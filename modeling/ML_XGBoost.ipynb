# %% [markdown]
# <a href="https://colab.research.google.com/github/minji0620/sk_broadband/blob/main/ML_XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/iptv_data_processed(28000).csv", encoding='cp949')
#df = pd.read_csv("/content/iptv_data_processed(50000).csv", encoding='cp949')

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_auc_score, classification_report
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import pickle

# %%
# 1. test set 분리
X_total = df.drop(columns=["iptv_yn"])
y_total = df["iptv_yn"]
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X_total, y_total, test_size=0.2, stratify=y_total, random_state=42
)

# 2. K-Fold 설정
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# 모델 성능 평가 함수 코드

# %%
def evaluate_xgb_model(params, X_trainval, y_trainval, X_test, y_test, cv=5, verbose=True):

    precision_0, recall_0, f1_0, support_0 = [], [], [], []
    precision_1, recall_1, f1_1, support_1 = [], [], [], []
    roc_auc_list = []

    skf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=42)

    for train_idx, val_idx in skf.split(X_trainval, y_trainval):
        X_train, X_val = X_trainval.iloc[train_idx], X_trainval.iloc[val_idx]
        y_train, y_val = y_trainval.iloc[train_idx], y_trainval.iloc[val_idx]

        model = XGBClassifier(**params)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_val)
        y_proba = model.predict_proba(X_val)[:, 1]
        report = classification_report(y_val, y_pred, output_dict=True)
        auc = roc_auc_score(y_val, y_proba)

        precision_0.append(report['0']['precision'])
        recall_0.append(report['0']['recall'])
        f1_0.append(report['0']['f1-score'])
        support_0.append(report['0']['support'])

        precision_1.append(report['1']['precision'])
        recall_1.append(report['1']['recall'])
        f1_1.append(report['1']['f1-score'])
        support_1.append(report['1']['support'])

        roc_auc_list.append(auc)

    # 평균 계산
    total_support_0 = np.mean(support_0)
    total_support_1 = np.mean(support_1)
    total_support = total_support_0 + total_support_1

    avg_p0, avg_r0, avg_f0 = np.mean(precision_0), np.mean(recall_0), np.mean(f1_0)
    avg_p1, avg_r1, avg_f1 = np.mean(precision_1), np.mean(recall_1), np.mean(f1_1)

    macro_precision = (avg_p0 + avg_p1) / 2
    macro_recall = (avg_r0 + avg_r1) / 2
    macro_f1 = (avg_f0 + avg_f1) / 2

    weighted_precision = (avg_p0 * total_support_0 + avg_p1 * total_support_1) / total_support
    weighted_recall = (avg_r0 * total_support_0 + avg_r1 * total_support_1) / total_support
    weighted_f1 = (avg_f0 * total_support_0 + avg_f1 * total_support_1) / total_support

    # 교차검증 결과 출력
    if verbose:
        print("📄 HPT 모델 성능 (5-Fold 평균 기반)")
        print(f"Class 0 - Precision: {avg_p0:.4f}, Recall: {avg_r0:.4f}, F1: {avg_f0:.4f}")
        print(f"Class 1 - Precision: {avg_p1:.4f}, Recall: {avg_r1:.4f}, F1: {avg_f1:.4f}")
        print(f"Macro Avg     - Precision: {macro_precision:.4f}, Recall: {macro_recall:.4f}, F1: {macro_f1:.4f}")
        print(f"Weighted Avg  - Precision: {weighted_precision:.4f}, Recall: {weighted_recall:.4f}, F1: {weighted_f1:.4f}")
        print(f"ROC AUC 평균: {np.mean(roc_auc_list):.4f}")

    # 최종 모델로 테스트셋 평가
    final_model = XGBClassifier(**params)
    final_model.fit(X_trainval, y_trainval)
    y_test_pred = final_model.predict(X_test)
    y_test_proba = final_model.predict_proba(X_test)[:, 1]

    if verbose:
        print("\n📊 HPT 모델 성능 (Test Set)")
        print(classification_report(y_test, y_test_pred))
        print(f"ROC AUC Score: {roc_auc_score(y_test, y_test_proba):.4f}")

    return {
        "cv": {
            "class_0": {"precision": avg_p0, "recall": avg_r0, "f1": avg_f0},
            "class_1": {"precision": avg_p1, "recall": avg_r1, "f1": avg_f1},
            "macro_avg": {"precision": macro_precision, "recall": macro_recall, "f1": macro_f1},
            "weighted_avg": {"precision": weighted_precision, "recall": weighted_recall, "f1": weighted_f1},
            "roc_auc": np.mean(roc_auc_list)
        },
        "test": {
            "classification_report": classification_report(y_test, y_test_pred, output_dict=True),
            "roc_auc": roc_auc_score(y_test, y_test_proba)
        }
    }

# %% [markdown]
# 모델 피클 파일 저장 함수

# %%
def save_model_and_results(model, scores, filename, selected_features = "All Selected"):
    """
    모델, 하이퍼파라미터, 성능 점수, 선택된 피처 리스트를 하나의 pickle 파일로 저장합니다.

    Parameters:
    - model: 학습된 모델 객체 (예: XGBClassifier)
    - scores: dict 형태의 성능 점수 (cv or test 등 자유롭게 구성 가능)
    - selected_features: list 형태의 선택된 feature 이름
    - filename: 저장할 경로 및 파일명 (.pkl)
    """
    save_object = {
        "model": model,
        "scores": scores,
        "selected_features": selected_features
    }

    with open(filename, "wb") as f:
        pickle.dump(save_object, f)

    return filename

# %% [markdown]
# 기본 모델 성능 확인

# %%
# 기본 모델 (파라미터 조정 X)
base_model=XGBClassifier(use_label_encoder=False,eval_metric='logloss',random_state=42)
base_params={'use_label_encoder':False, 'eval_metric':'logloss', 'random_state':42}

base_results = evaluate_xgb_model(base_params, X_trainval, y_trainval, X_test, y_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📄 HPT 모델 성능 (5-Fold 평균 기반)
# Class 0 - Precision: 0.5941, Recall: 0.3564, F1: 0.4454
# Class 1 - Precision: 0.9148, Recall: 0.9660, F1: 0.9397
# Macro Avg     - Precision: 0.7545, Recall: 0.6612, F1: 0.6925
# Weighted Avg  - Precision: 0.8754, Recall: 0.8912, F1: 0.8790
# ROC AUC 평균: 0.8920
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [08:18:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📊 HPT 모델 성능 (Test Set)
#               precision    recall  f1-score   support
#
#            0       0.59      0.36      0.45      1028
#            1       0.92      0.96      0.94      7353
#
#     accuracy                           0.89      8381
#    macro avg       0.75      0.66      0.69      8381
# weighted avg       0.88      0.89      0.88      8381
#
# ROC AUC Score: 0.8941

# %%
save_model_and_results(base_model, base_results, "/content/xgb_base_model_50.pkl")
# Out:
# '/content/xgb_base_model_50.pkl'

# %%
# !pip install optuna
import optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 8.2 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 23.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.2.1

# %%
# 1차 튜닝
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 15),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.3, 1.0),
        'use_label_encoder': False,
        'eval_metric': 'logloss',
        'random_state': 42
    }

    model = XGBClassifier(**params)
    score = cross_val_score(model, X_trainval, y_trainval, cv=skf, scoring='roc_auc', n_jobs=-1)
    return np.mean(score)

# Study 정의 및 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# 최적 결과 출력
print("✅ Best trial:")
print("AUC:", study.best_value)
print("Params:", study.best_params)
# Out:
# [I 2025-04-10 08:20:08,799] A new study created in memory with name: no-name-690cb959-1cc3-4865-8368-de73618f6003
# [I 2025-04-10 08:20:11,998] Trial 0 finished with value: 0.9003340660641801 and parameters: {'n_estimators': 361, 'max_depth': 3, 'learning_rate': 0.2245396976117129, 'min_child_weight': 12, 'gamma': 2.949878668171184, 'subsample': 0.6842126027873047, 'colsample_bytree': 0.7931639640450332, 'scale_pos_weight': 0.47684024459226276}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:14,232] Trial 1 finished with value: 0.9002938304055681 and parameters: {'n_estimators': 369, 'max_depth': 4, 'learning_rate': 0.1747334276231886, 'min_child_weight': 1, 'gamma': 3.403093062004362, 'subsample': 0.9008727877455318, 'colsample_bytree': 0.955758753259873, 'scale_pos_weight': 0.5338882825896373}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:15,769] Trial 2 finished with value: 0.880272533058787 and parameters: {'n_estimators': 348, 'max_depth': 6, 'learning_rate': 0.23772727462616572, 'min_child_weight': 5, 'gamma': 0.28226732043900526, 'subsample': 0.719212935103617, 'colsample_bytree': 0.7031184077094872, 'scale_pos_weight': 0.9883270065216787}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:17,501] Trial 3 finished with value: 0.8766220477258709 and parameters: {'n_estimators': 349, 'max_depth': 6, 'learning_rate': 0.2265709066798052, 'min_child_weight': 1, 'gamma': 0.5931488045519728, 'subsample': 0.5082108697533891, 'colsample_bytree': 0.8243056447020866, 'scale_pos_weight': 0.8525729637006842}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:18,370] Trial 4 finished with value: 0.8993352312037823 and parameters: {'n_estimators': 310, 'max_depth': 8, 'learning_rate': 0.23132630708482554, 'min_child_weight': 15, 'gamma': 0.8994669382661724, 'subsample': 0.904471560114605, 'colsample_bytree': 0.5150648942836775, 'scale_pos_weight': 0.3503152613174214}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:18,977] Trial 5 finished with value: 0.8986626430992661 and parameters: {'n_estimators': 201, 'max_depth': 3, 'learning_rate': 0.2351299882922812, 'min_child_weight': 10, 'gamma': 3.292107645190179, 'subsample': 0.8340171649162103, 'colsample_bytree': 0.5487653348355388, 'scale_pos_weight': 0.7942437504082643}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:20,433] Trial 6 finished with value: 0.9000064459035293 and parameters: {'n_estimators': 455, 'max_depth': 10, 'learning_rate': 0.065728313802087, 'min_child_weight': 15, 'gamma': 1.4938705423381093, 'subsample': 0.7214467381447798, 'colsample_bytree': 0.589330934091749, 'scale_pos_weight': 0.40688896547235964}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:21,162] Trial 7 finished with value: 0.8978561325452606 and parameters: {'n_estimators': 177, 'max_depth': 3, 'learning_rate': 0.2540392325419093, 'min_child_weight': 10, 'gamma': 0.05878295277882806, 'subsample': 0.5410098760689741, 'colsample_bytree': 0.7227056836995769, 'scale_pos_weight': 0.411557068917144}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:21,885] Trial 8 finished with value: 0.8972274634552377 and parameters: {'n_estimators': 192, 'max_depth': 9, 'learning_rate': 0.26829975457363114, 'min_child_weight': 3, 'gamma': 3.956700265126483, 'subsample': 0.5857891705120776, 'colsample_bytree': 0.6997803878282838, 'scale_pos_weight': 0.6411847159577635}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:22,431] Trial 9 finished with value: 0.8990281228656926 and parameters: {'n_estimators': 138, 'max_depth': 9, 'learning_rate': 0.18564934235244437, 'min_child_weight': 7, 'gamma': 2.940955271430533, 'subsample': 0.8278380112701479, 'colsample_bytree': 0.6293299721954757, 'scale_pos_weight': 0.5101657765372513}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:23,620] Trial 10 finished with value: 0.899649859294214 and parameters: {'n_estimators': 485, 'max_depth': 5, 'learning_rate': 0.09357624426914296, 'min_child_weight': 12, 'gamma': 4.925531242011928, 'subsample': 0.635905676209108, 'colsample_bytree': 0.8710503952931041, 'scale_pos_weight': 0.6303576138863104}. Best is trial 0 with value: 0.9003340660641801.
# [I 2025-04-10 08:20:24,574] Trial 11 finished with value: 0.900341843133804 and parameters: {'n_estimators': 413, 'max_depth': 4, 'learning_rate': 0.1479446706544466, 'min_child_weight': 12, 'gamma': 1.9094467347417483, 'subsample': 0.971004095627723, 'colsample_bytree': 0.9634027564240464, 'scale_pos_weight': 0.5146672163178789}. Best is trial 11 with value: 0.900341843133804.
# [I 2025-04-10 08:20:25,558] Trial 12 finished with value: 0.9004432310155996 and parameters: {'n_estimators': 420, 'max_depth': 4, 'learning_rate': 0.12134832041843005, 'min_child_weight': 12, 'gamma': 1.981973371058468, 'subsample': 0.9552365973896267, 'colsample_bytree': 0.9999241469920368, 'scale_pos_weight': 0.5203434433105665}. Best is trial 12 with value: 0.9004432310155996.
# [I 2025-04-10 08:20:26,576] Trial 13 finished with value: 0.9005001469983871 and parameters: {'n_estimators': 428, 'max_depth': 5, 'learning_rate': 0.11727520752082765, 'min_child_weight': 12, 'gamma': 2.0985062983982843, 'subsample': 0.9856275007733497, 'colsample_bytree': 0.9981930235417237, 'scale_pos_weight': 0.7220536067932766}. Best is trial 13 with value: 0.9005001469983871.
# [I 2025-04-10 08:20:27,573] Trial 14 finished with value: 0.8998748635773438 and parameters: {'n_estimators': 430, 'max_depth': 5, 'learning_rate': 0.11781277171872559, 'min_child_weight': 9, 'gamma': 2.048341554859812, 'subsample': 0.9945916563649162, 'colsample_bytree': 0.9900445592458594, 'scale_pos_weight': 0.7624644547308941}. Best is trial 13 with value: 0.9005001469983871.
# [I 2025-04-10 08:20:28,891] Trial 15 finished with value: 0.8972400992462178 and parameters: {'n_estimators': 272, 'max_depth': 7, 'learning_rate': 0.012175236098107362, 'min_child_weight': 13, 'gamma': 1.38322419658605, 'subsample': 0.9199681946598058, 'colsample_bytree': 0.8968964350567756, 'scale_pos_weight': 0.7468009498405686}. Best is trial 13 with value: 0.9005001469983871.
# [I 2025-04-10 08:20:30,176] Trial 16 finished with value: 0.9016890431891251 and parameters: {'n_estimators': 487, 'max_depth': 4, 'learning_rate': 0.060567051046631126, 'min_child_weight': 7, 'gamma': 2.5424968715252856, 'subsample': 0.8189956194328952, 'colsample_bytree': 0.9095185622914687, 'scale_pos_weight': 0.5891524854565151}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:31,647] Trial 17 finished with value: 0.9012410973390006 and parameters: {'n_estimators': 484, 'max_depth': 5, 'learning_rate': 0.03898426814100085, 'min_child_weight': 5, 'gamma': 2.4989029279855006, 'subsample': 0.815677982886201, 'colsample_bytree': 0.9054874804583153, 'scale_pos_weight': 0.9097587629117929}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:33,640] Trial 18 finished with value: 0.8997782672991228 and parameters: {'n_estimators': 487, 'max_depth': 7, 'learning_rate': 0.012011327075495602, 'min_child_weight': 7, 'gamma': 4.068002671143363, 'subsample': 0.8012084166240476, 'colsample_bytree': 0.9020948532571285, 'scale_pos_weight': 0.9512527246968892}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:34,611] Trial 19 finished with value: 0.9007619593784277 and parameters: {'n_estimators': 259, 'max_depth': 5, 'learning_rate': 0.05368346241997216, 'min_child_weight': 5, 'gamma': 2.6480211908198066, 'subsample': 0.7903530592102076, 'colsample_bytree': 0.7926987491252897, 'scale_pos_weight': 0.8379976796668089}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:35,934] Trial 20 finished with value: 0.9000129618266266 and parameters: {'n_estimators': 498, 'max_depth': 6, 'learning_rate': 0.042366194223978644, 'min_child_weight': 5, 'gamma': 3.815039019338366, 'subsample': 0.8712624400736703, 'colsample_bytree': 0.8529079736378675, 'scale_pos_weight': 0.9049403528796841}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:36,963] Trial 21 finished with value: 0.9009899400698854 and parameters: {'n_estimators': 272, 'max_depth': 5, 'learning_rate': 0.048840625178561387, 'min_child_weight': 5, 'gamma': 2.499471213524982, 'subsample': 0.7696998867847497, 'colsample_bytree': 0.7847871623748173, 'scale_pos_weight': 0.8582511301180769}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:37,841] Trial 22 finished with value: 0.9016231458278373 and parameters: {'n_estimators': 238, 'max_depth': 4, 'learning_rate': 0.07783850794960762, 'min_child_weight': 3, 'gamma': 2.447606139958216, 'subsample': 0.7682016349864854, 'colsample_bytree': 0.9236374021806931, 'scale_pos_weight': 0.899708766304499}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:38,741] Trial 23 finished with value: 0.9009144925080296 and parameters: {'n_estimators': 226, 'max_depth': 4, 'learning_rate': 0.08118152327596828, 'min_child_weight': 3, 'gamma': 2.3937089334861072, 'subsample': 0.8473945410413749, 'colsample_bytree': 0.9391866611641543, 'scale_pos_weight': 0.687520419125614}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:39,391] Trial 24 finished with value: 0.8919668752873064 and parameters: {'n_estimators': 124, 'max_depth': 4, 'learning_rate': 0.03262427727932743, 'min_child_weight': 3, 'gamma': 1.3919941255365007, 'subsample': 0.7387955793422185, 'colsample_bytree': 0.9095943743534407, 'scale_pos_weight': 0.5967864883217149}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:40,415] Trial 25 finished with value: 0.9010628498552213 and parameters: {'n_estimators': 311, 'max_depth': 3, 'learning_rate': 0.09065991850363737, 'min_child_weight': 7, 'gamma': 2.9631309723420176, 'subsample': 0.6822248808233968, 'colsample_bytree': 0.9301733944525429, 'scale_pos_weight': 0.9412994724096875}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:41,787] Trial 26 finished with value: 0.9015581449340118 and parameters: {'n_estimators': 467, 'max_depth': 4, 'learning_rate': 0.07756205524017082, 'min_child_weight': 4, 'gamma': 1.6637747213189362, 'subsample': 0.7673603046464523, 'colsample_bytree': 0.8545702256328018, 'scale_pos_weight': 0.593984356691304}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:43,079] Trial 27 finished with value: 0.9013897105615293 and parameters: {'n_estimators': 385, 'max_depth': 4, 'learning_rate': 0.07088734422590018, 'min_child_weight': 2, 'gamma': 1.600029990081609, 'subsample': 0.7667799232531074, 'colsample_bytree': 0.846679432243846, 'scale_pos_weight': 0.6899863577315913}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:43,937] Trial 28 finished with value: 0.9006102599456778 and parameters: {'n_estimators': 228, 'max_depth': 3, 'learning_rate': 0.10442698348421413, 'min_child_weight': 4, 'gamma': 0.9341539310665783, 'subsample': 0.6986005198634073, 'colsample_bytree': 0.8206333642400871, 'scale_pos_weight': 0.5831281261022897}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:45,254] Trial 29 finished with value: 0.9006949230527909 and parameters: {'n_estimators': 449, 'max_depth': 3, 'learning_rate': 0.1413527282858983, 'min_child_weight': 8, 'gamma': 2.913956075112157, 'subsample': 0.6572607400710841, 'colsample_bytree': 0.7691929046099817, 'scale_pos_weight': 0.47227859570736397}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:46,610] Trial 30 finished with value: 0.900016525133536 and parameters: {'n_estimators': 391, 'max_depth': 6, 'learning_rate': 0.06842873776430797, 'min_child_weight': 6, 'gamma': 1.0458181977130336, 'subsample': 0.8683589773508861, 'colsample_bytree': 0.8809910152334909, 'scale_pos_weight': 0.5828295151137403}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:47,972] Trial 31 finished with value: 0.9012129035159353 and parameters: {'n_estimators': 454, 'max_depth': 4, 'learning_rate': 0.07265884238284755, 'min_child_weight': 2, 'gamma': 1.7038112660481248, 'subsample': 0.7672340437127008, 'colsample_bytree': 0.8415000426245884, 'scale_pos_weight': 0.6911601151879824}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:49,003] Trial 32 finished with value: 0.8992186282897086 and parameters: {'n_estimators': 380, 'max_depth': 4, 'learning_rate': 0.17974507291443548, 'min_child_weight': 1, 'gamma': 2.20239414643038, 'subsample': 0.7636433552946931, 'colsample_bytree': 0.8125203271244408, 'scale_pos_weight': 0.6779422816669247}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:50,223] Trial 33 finished with value: 0.8986212213968378 and parameters: {'n_estimators': 334, 'max_depth': 4, 'learning_rate': 0.02682101350940335, 'min_child_weight': 2, 'gamma': 1.7506702348307353, 'subsample': 0.7402227694304512, 'colsample_bytree': 0.8591228692093873, 'scale_pos_weight': 0.5725947770073962}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:51,212] Trial 34 finished with value: 0.9001818046000123 and parameters: {'n_estimators': 403, 'max_depth': 3, 'learning_rate': 0.20324596163222075, 'min_child_weight': 4, 'gamma': 3.365874233132104, 'subsample': 0.7863338358436666, 'colsample_bytree': 0.9604297688291352, 'scale_pos_weight': 0.6243101982971203}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:53,082] Trial 35 finished with value: 0.8966303834765471 and parameters: {'n_estimators': 467, 'max_depth': 6, 'learning_rate': 0.060440484742051465, 'min_child_weight': 2, 'gamma': 0.5627619121053569, 'subsample': 0.8628557603362643, 'colsample_bytree': 0.9344559137624167, 'scale_pos_weight': 0.4535715097222094}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:54,405] Trial 36 finished with value: 0.8979972794264051 and parameters: {'n_estimators': 370, 'max_depth': 5, 'learning_rate': 0.09718044665266212, 'min_child_weight': 4, 'gamma': 1.6061337180052047, 'subsample': 0.6816955515450348, 'colsample_bytree': 0.762686048248016, 'scale_pos_weight': 0.8191591150635431}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:55,397] Trial 37 finished with value: 0.9004316466875089 and parameters: {'n_estimators': 334, 'max_depth': 3, 'learning_rate': 0.1348990249293713, 'min_child_weight': 1, 'gamma': 2.2722987919620428, 'subsample': 0.7187620343013329, 'colsample_bytree': 0.8370736830715183, 'scale_pos_weight': 0.35111216191006944}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:56,813] Trial 38 finished with value: 0.9010356230905033 and parameters: {'n_estimators': 440, 'max_depth': 4, 'learning_rate': 0.08332106179355415, 'min_child_weight': 6, 'gamma': 1.2073906298381125, 'subsample': 0.9000064457635578, 'colsample_bytree': 0.6679816707492108, 'scale_pos_weight': 0.5462068935039308}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:58,066] Trial 39 finished with value: 0.8957858461801089 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.1662243338508979, 'min_child_weight': 3, 'gamma': 0.7876540308415214, 'subsample': 0.8082126616174853, 'colsample_bytree': 0.8816563538451975, 'scale_pos_weight': 0.724463585594095}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:20:59,622] Trial 40 finished with value: 0.9004372725798063 and parameters: {'n_estimators': 469, 'max_depth': 7, 'learning_rate': 0.05685343520465313, 'min_child_weight': 2, 'gamma': 2.664887725672196, 'subsample': 0.6159120135573168, 'colsample_bytree': 0.7359581582689712, 'scale_pos_weight': 0.9842507425832328}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:01,048] Trial 41 finished with value: 0.9010814722384847 and parameters: {'n_estimators': 475, 'max_depth': 5, 'learning_rate': 0.03447711791532145, 'min_child_weight': 6, 'gamma': 3.132877084929507, 'subsample': 0.8201313482752163, 'colsample_bytree': 0.9167273999655653, 'scale_pos_weight': 0.8955432468964982}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:02,169] Trial 42 finished with value: 0.8992925774281767 and parameters: {'n_estimators': 498, 'max_depth': 5, 'learning_rate': 0.2884903766475243, 'min_child_weight': 4, 'gamma': 2.6124548977717814, 'subsample': 0.8374282419650175, 'colsample_bytree': 0.9592948975082354, 'scale_pos_weight': 0.7891134645640667}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:03,424] Trial 43 finished with value: 0.9005469252845988 and parameters: {'n_estimators': 397, 'max_depth': 4, 'learning_rate': 0.07295002882812, 'min_child_weight': 8, 'gamma': 3.606480789601155, 'subsample': 0.7507482534318941, 'colsample_bytree': 0.8820192149102681, 'scale_pos_weight': 0.9018763771775774}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:04,101] Trial 44 finished with value: 0.8793593730676671 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.023952369018676124, 'min_child_weight': 6, 'gamma': 1.8195438227960614, 'subsample': 0.7170035979927268, 'colsample_bytree': 0.8107788992917329, 'scale_pos_weight': 0.8647581598154903}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:05,335] Trial 45 finished with value: 0.9005868384283652 and parameters: {'n_estimators': 465, 'max_depth': 6, 'learning_rate': 0.10634254673038859, 'min_child_weight': 3, 'gamma': 2.840914686486777, 'subsample': 0.7967444595312798, 'colsample_bytree': 0.8634522408635116, 'scale_pos_weight': 0.9946283637828177}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:06,659] Trial 46 finished with value: 0.9016268088988028 and parameters: {'n_estimators': 440, 'max_depth': 4, 'learning_rate': 0.04276468129768381, 'min_child_weight': 9, 'gamma': 2.395229930963188, 'subsample': 0.8219113999179499, 'colsample_bytree': 0.9771311177704609, 'scale_pos_weight': 0.6527960732974701}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:07,972] Trial 47 finished with value: 0.899927224489921 and parameters: {'n_estimators': 437, 'max_depth': 10, 'learning_rate': 0.0802209232938272, 'min_child_weight': 10, 'gamma': 2.2082000013357197, 'subsample': 0.7814480918669493, 'colsample_bytree': 0.9722000231370306, 'scale_pos_weight': 0.6486696777282507}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:09,235] Trial 48 finished with value: 0.9012851256657054 and parameters: {'n_estimators': 409, 'max_depth': 4, 'learning_rate': 0.051929904635568305, 'min_child_weight': 9, 'gamma': 1.9189260652249338, 'subsample': 0.9168616313074761, 'colsample_bytree': 0.9417826769286677, 'scale_pos_weight': 0.5463518633382006}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:10,137] Trial 49 finished with value: 0.8980365215477875 and parameters: {'n_estimators': 229, 'max_depth': 9, 'learning_rate': 0.1253816759767183, 'min_child_weight': 9, 'gamma': 1.2370867502915726, 'subsample': 0.852549122263737, 'colsample_bytree': 0.9809845392867151, 'scale_pos_weight': 0.6102117317914901}. Best is trial 16 with value: 0.9016890431891251.
# [I 2025-04-10 08:21:11,218] Trial 50 finished with value: 0.901733509970344 and parameters: {'n_estimators': 421, 'max_depth': 3, 'learning_rate': 0.1056657294942845, 'min_child_weight': 11, 'gamma': 1.537445767391795, 'subsample': 0.8931164133098327, 'colsample_bytree': 0.9290710442530649, 'scale_pos_weight': 0.6659544711836847}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:12,309] Trial 51 finished with value: 0.9015014794893904 and parameters: {'n_estimators': 421, 'max_depth': 3, 'learning_rate': 0.10822459100976606, 'min_child_weight': 11, 'gamma': 1.472430033454482, 'subsample': 0.8894189915691956, 'colsample_bytree': 0.9188269374506502, 'scale_pos_weight': 0.6703184135280418}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:13,595] Trial 52 finished with value: 0.9002681665794887 and parameters: {'n_estimators': 424, 'max_depth': 3, 'learning_rate': 0.11089863949233059, 'min_child_weight': 13, 'gamma': 0.2907688997643123, 'subsample': 0.8853332477349619, 'colsample_bytree': 0.9475638149551335, 'scale_pos_weight': 0.6591898357571253}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:14,688] Trial 53 finished with value: 0.9004779663388266 and parameters: {'n_estimators': 450, 'max_depth': 3, 'learning_rate': 0.08834196668201597, 'min_child_weight': 11, 'gamma': 2.0200423251389217, 'subsample': 0.9406946628149568, 'colsample_bytree': 0.92305303862195, 'scale_pos_weight': 0.7161545845069348}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:15,691] Trial 54 finished with value: 0.899819567061052 and parameters: {'n_estimators': 418, 'max_depth': 3, 'learning_rate': 0.12841659016205725, 'min_child_weight': 11, 'gamma': 2.391109040796148, 'subsample': 0.9340706468146261, 'colsample_bytree': 0.9754700351577372, 'scale_pos_weight': 0.49117044797535064}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:16,844] Trial 55 finished with value: 0.901213492824057 and parameters: {'n_estimators': 481, 'max_depth': 3, 'learning_rate': 0.15281171971582438, 'min_child_weight': 11, 'gamma': 1.5060286626853092, 'subsample': 0.9039480911695494, 'colsample_bytree': 0.895353442332298, 'scale_pos_weight': 0.7634432628391122}. Best is trial 50 with value: 0.901733509970344.
# [I 2025-04-10 08:21:17,617] Trial 56 finished with value: 0.9017352366332195 and parameters: {'n_estimators': 195, 'max_depth': 4, 'learning_rate': 0.09563940358400486, 'min_child_weight': 14, 'gamma': 1.242268669141998, 'subsample': 0.8881746398775934, 'colsample_bytree': 0.9204006284324615, 'scale_pos_weight': 0.6308914507048188}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:18,409] Trial 57 finished with value: 0.8988987494110917 and parameters: {'n_estimators': 168, 'max_depth': 8, 'learning_rate': 0.04180061720993299, 'min_child_weight': 15, 'gamma': 4.32081051746804, 'subsample': 0.8299570738197521, 'colsample_bytree': 0.9559684671363027, 'scale_pos_weight': 0.56000363344724}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:19,280] Trial 58 finished with value: 0.9013703382896839 and parameters: {'n_estimators': 201, 'max_depth': 4, 'learning_rate': 0.09818011681217832, 'min_child_weight': 14, 'gamma': 1.1310608121381285, 'subsample': 0.8420281354217375, 'colsample_bytree': 0.9964474634889884, 'scale_pos_weight': 0.621207753600193}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:20,194] Trial 59 finished with value: 0.8978668486491627 and parameters: {'n_estimators': 254, 'max_depth': 5, 'learning_rate': 0.04847379715204406, 'min_child_weight': 14, 'gamma': 3.124090058644728, 'subsample': 0.9558205343082931, 'colsample_bytree': 0.5245491824692712, 'scale_pos_weight': 0.6373355604246319}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:21,144] Trial 60 finished with value: 0.9005258120696438 and parameters: {'n_estimators': 212, 'max_depth': 4, 'learning_rate': 0.06296038894502327, 'min_child_weight': 10, 'gamma': 1.306065453278695, 'subsample': 0.5147407518843522, 'colsample_bytree': 0.8954042814139656, 'scale_pos_weight': 0.520545050303579}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:22,087] Trial 61 finished with value: 0.9013100285848138 and parameters: {'n_estimators': 284, 'max_depth': 3, 'learning_rate': 0.11357658034000606, 'min_child_weight': 14, 'gamma': 0.8307863523740773, 'subsample': 0.8773977927616095, 'colsample_bytree': 0.9231094399794054, 'scale_pos_weight': 0.6674142862058529}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:22,849] Trial 62 finished with value: 0.9011834661678438 and parameters: {'n_estimators': 178, 'max_depth': 4, 'learning_rate': 0.09810001663020063, 'min_child_weight': 13, 'gamma': 0.5724466087969474, 'subsample': 0.8977842740134293, 'colsample_bytree': 0.9088477266873177, 'scale_pos_weight': 0.5970206240368839}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:24,014] Trial 63 finished with value: 0.9012394104549035 and parameters: {'n_estimators': 441, 'max_depth': 3, 'learning_rate': 0.07701338401983052, 'min_child_weight': 9, 'gamma': 1.8181997630707172, 'subsample': 0.885463689997435, 'colsample_bytree': 0.9424914521731881, 'scale_pos_weight': 0.711839357313843}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:25,363] Trial 64 finished with value: 0.9005965208863127 and parameters: {'n_estimators': 460, 'max_depth': 4, 'learning_rate': 0.0871583626425601, 'min_child_weight': 11, 'gamma': 1.4012579691706266, 'subsample': 0.8169929615162709, 'colsample_bytree': 0.8709405046592021, 'scale_pos_weight': 0.7483316574327332}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:27,314] Trial 65 finished with value: 0.9006792196207296 and parameters: {'n_estimators': 490, 'max_depth': 5, 'learning_rate': 0.019155835873462243, 'min_child_weight': 12, 'gamma': 2.077211364528738, 'subsample': 0.8583469433806796, 'colsample_bytree': 0.9289910399540965, 'scale_pos_weight': 0.6401804110439294}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:28,258] Trial 66 finished with value: 0.8994235839283025 and parameters: {'n_estimators': 298, 'max_depth': 3, 'learning_rate': 0.06209458327266182, 'min_child_weight': 8, 'gamma': 1.5606011386706338, 'subsample': 0.9266042568577525, 'colsample_bytree': 0.5988239743493822, 'scale_pos_weight': 0.6051666081578547}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:29,212] Trial 67 finished with value: 0.9000369954476083 and parameters: {'n_estimators': 242, 'max_depth': 4, 'learning_rate': 0.10735882847895363, 'min_child_weight': 7, 'gamma': 0.940024628159609, 'subsample': 0.7505534460194218, 'colsample_bytree': 0.981865332788289, 'scale_pos_weight': 0.5801513699183445}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:29,753] Trial 68 finished with value: 0.8985412713539956 and parameters: {'n_estimators': 120, 'max_depth': 4, 'learning_rate': 0.13749591707525116, 'min_child_weight': 10, 'gamma': 2.7561268285538434, 'subsample': 0.9769565584431116, 'colsample_bytree': 0.891061136961643, 'scale_pos_weight': 0.4325261095857554}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:30,506] Trial 69 finished with value: 0.8998652089293342 and parameters: {'n_estimators': 198, 'max_depth': 3, 'learning_rate': 0.09438584274200856, 'min_child_weight': 12, 'gamma': 2.3527634780057336, 'subsample': 0.7805773115159876, 'colsample_bytree': 0.9129725164883882, 'scale_pos_weight': 0.7032496613205271}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:31,785] Trial 70 finished with value: 0.8932333720716035 and parameters: {'n_estimators': 369, 'max_depth': 5, 'learning_rate': 0.19632807945694036, 'min_child_weight': 8, 'gamma': 1.0578048571460719, 'subsample': 0.8029592166147743, 'colsample_bytree': 0.9612738658265357, 'scale_pos_weight': 0.6600326935037387}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:33,148] Trial 71 finished with value: 0.9010695884346411 and parameters: {'n_estimators': 385, 'max_depth': 4, 'learning_rate': 0.06874318400916918, 'min_child_weight': 1, 'gamma': 1.663069380009695, 'subsample': 0.7342251326590303, 'colsample_bytree': 0.8504883839331294, 'scale_pos_weight': 0.6870049422408949}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:33,708] Trial 72 finished with value: 0.8970567748515208 and parameters: {'n_estimators': 101, 'max_depth': 4, 'learning_rate': 0.07604875757192871, 'min_child_weight': 2, 'gamma': 1.4830327442589497, 'subsample': 0.7625067600769354, 'colsample_bytree': 0.8300232241812775, 'scale_pos_weight': 0.6235190352937262}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:34,976] Trial 73 finished with value: 0.9009309565379351 and parameters: {'n_estimators': 435, 'max_depth': 4, 'learning_rate': 0.04563580971141911, 'min_child_weight': 9, 'gamma': 2.509106944970905, 'subsample': 0.8349768986866624, 'colsample_bytree': 0.8675163720647914, 'scale_pos_weight': 0.6753398286929859}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:36,244] Trial 74 finished with value: 0.9012367594506232 and parameters: {'n_estimators': 412, 'max_depth': 3, 'learning_rate': 0.05792401347194522, 'min_child_weight': 3, 'gamma': 1.8613560546067025, 'subsample': 0.7039392925272427, 'colsample_bytree': 0.9303697549230054, 'scale_pos_weight': 0.5487412397899957}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:37,783] Trial 75 finished with value: 0.8986449999439449 and parameters: {'n_estimators': 450, 'max_depth': 4, 'learning_rate': 0.08440961231272527, 'min_child_weight': 4, 'gamma': 0.7229633885260227, 'subsample': 0.7743651660217575, 'colsample_bytree': 0.9045050421573125, 'scale_pos_weight': 0.7343488296496088}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:39,042] Trial 76 finished with value: 0.901399397768144 and parameters: {'n_estimators': 426, 'max_depth': 5, 'learning_rate': 0.06794729106567213, 'min_child_weight': 7, 'gamma': 2.142940270960082, 'subsample': 0.792658757210375, 'colsample_bytree': 0.8463168374669126, 'scale_pos_weight': 0.7688555762237272}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:40,218] Trial 77 finished with value: 0.900590000894511 and parameters: {'n_estimators': 426, 'max_depth': 5, 'learning_rate': 0.10224155499783844, 'min_child_weight': 7, 'gamma': 2.158989484014052, 'subsample': 0.7932650938583905, 'colsample_bytree': 0.9515246385153301, 'scale_pos_weight': 0.8137103930592381}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:41,729] Trial 78 finished with value: 0.901302090710853 and parameters: {'n_estimators': 485, 'max_depth': 5, 'learning_rate': 0.03410868330507352, 'min_child_weight': 5, 'gamma': 2.5260818135534233, 'subsample': 0.8136171164953893, 'colsample_bytree': 0.7958121572570327, 'scale_pos_weight': 0.875603955573283}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:42,473] Trial 79 finished with value: 0.9004566111236064 and parameters: {'n_estimators': 215, 'max_depth': 3, 'learning_rate': 0.11717278365906166, 'min_child_weight': 10, 'gamma': 1.9292340235267829, 'subsample': 0.8506282515462887, 'colsample_bytree': 0.6899878356560941, 'scale_pos_weight': 0.564643552637032}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:43,541] Trial 80 finished with value: 0.9017176953625633 and parameters: {'n_estimators': 337, 'max_depth': 4, 'learning_rate': 0.09053755944554247, 'min_child_weight': 6, 'gamma': 1.692728726249683, 'subsample': 0.8818022525877556, 'colsample_bytree': 0.8830792897746043, 'scale_pos_weight': 0.9506109879562626}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:44,560] Trial 81 finished with value: 0.9014902573590253 and parameters: {'n_estimators': 330, 'max_depth': 4, 'learning_rate': 0.09026546155787435, 'min_child_weight': 6, 'gamma': 1.7072624002748158, 'subsample': 0.9142748530321629, 'colsample_bytree': 0.8772134584452037, 'scale_pos_weight': 0.9338269773535158}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:45,589] Trial 82 finished with value: 0.9016129088303428 and parameters: {'n_estimators': 336, 'max_depth': 4, 'learning_rate': 0.09315401799589727, 'min_child_weight': 5, 'gamma': 1.3878183191868834, 'subsample': 0.911254713958093, 'colsample_bytree': 0.8807275041491949, 'scale_pos_weight': 0.9362125034927415}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:46,565] Trial 83 finished with value: 0.9010430926649441 and parameters: {'n_estimators': 317, 'max_depth': 4, 'learning_rate': 0.12205649205943121, 'min_child_weight': 5, 'gamma': 1.4197316486477696, 'subsample': 0.8807790117984212, 'colsample_bytree': 0.8879605714524176, 'scale_pos_weight': 0.9804554310979378}. Best is trial 56 with value: 0.9017352366332195.
# [I 2025-04-10 08:21:47,550] Trial 84 finished with value: 0.9018574284282022 and parameters: {'n_estimators': 285, 'max_depth': 4, 'learning_rate': 0.08159743695042095, 'min_child_weight': 4, 'gamma': 1.2449394970977086, 'subsample': 0.8915439147949505, 'colsample_bytree': 0.9141412503037608, 'scale_pos_weight': 0.5843248205910467}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:48,545] Trial 85 finished with value: 0.9017685335258229 and parameters: {'n_estimators': 273, 'max_depth': 4, 'learning_rate': 0.07675471539146558, 'min_child_weight': 4, 'gamma': 1.2281977200793799, 'subsample': 0.8713934219411413, 'colsample_bytree': 0.9399599378392961, 'scale_pos_weight': 0.9751019184344335}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:49,602] Trial 86 finished with value: 0.9014638113326807 and parameters: {'n_estimators': 289, 'max_depth': 4, 'learning_rate': 0.0562513418535494, 'min_child_weight': 5, 'gamma': 1.2725663885507987, 'subsample': 0.8706356219292409, 'colsample_bytree': 0.9728518766855467, 'scale_pos_weight': 0.9506949601561354}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:50,574] Trial 87 finished with value: 0.8997379019841313 and parameters: {'n_estimators': 263, 'max_depth': 8, 'learning_rate': 0.08272149216252167, 'min_child_weight': 6, 'gamma': 1.1104024629741025, 'subsample': 0.9439139158843728, 'colsample_bytree': 0.9393929675461214, 'scale_pos_weight': 0.9171555368712996}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:51,499] Trial 88 finished with value: 0.9014717259785237 and parameters: {'n_estimators': 270, 'max_depth': 4, 'learning_rate': 0.09179260491849263, 'min_child_weight': 4, 'gamma': 1.3040623761970358, 'subsample': 0.9136980736922083, 'colsample_bytree': 0.9068091797153847, 'scale_pos_weight': 0.9630687414142781}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:52,395] Trial 89 finished with value: 0.9000641920147776 and parameters: {'n_estimators': 345, 'max_depth': 5, 'learning_rate': 0.2471102508667306, 'min_child_weight': 5, 'gamma': 1.1392290485229533, 'subsample': 0.957682116401356, 'colsample_bytree': 0.9916814262768406, 'scale_pos_weight': 0.8835876651665858}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:53,331] Trial 90 finished with value: 0.9014756721375174 and parameters: {'n_estimators': 245, 'max_depth': 4, 'learning_rate': 0.07355067791530441, 'min_child_weight': 5, 'gamma': 0.3732996883330221, 'subsample': 0.8972435562957913, 'colsample_bytree': 0.9648856003621975, 'scale_pos_weight': 0.9689451811706893}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:54,439] Trial 91 finished with value: 0.9015583584360259 and parameters: {'n_estimators': 316, 'max_depth': 4, 'learning_rate': 0.07931883675146495, 'min_child_weight': 4, 'gamma': 0.9902665386953085, 'subsample': 0.8682447880781106, 'colsample_bytree': 0.9185350950355602, 'scale_pos_weight': 0.9154919305582007}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:55,560] Trial 92 finished with value: 0.9002103198935348 and parameters: {'n_estimators': 308, 'max_depth': 4, 'learning_rate': 0.10026578158231558, 'min_child_weight': 3, 'gamma': 0.9647973809128286, 'subsample': 0.8665234546610847, 'colsample_bytree': 0.9469532508984781, 'scale_pos_weight': 0.8399969798226712}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:56,819] Trial 93 finished with value: 0.9015320409826616 and parameters: {'n_estimators': 322, 'max_depth': 4, 'learning_rate': 0.0643719148207954, 'min_child_weight': 4, 'gamma': 0.6791715743373149, 'subsample': 0.8541540159744935, 'colsample_bytree': 0.9223367926720398, 'scale_pos_weight': 0.9302792498981579}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:57,870] Trial 94 finished with value: 0.9011382138136724 and parameters: {'n_estimators': 280, 'max_depth': 4, 'learning_rate': 0.07978140344601915, 'min_child_weight': 4, 'gamma': 0.4665395913218222, 'subsample': 0.823957784177232, 'colsample_bytree': 0.899075961682915, 'scale_pos_weight': 0.9219106338313253}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:21:58,878] Trial 95 finished with value: 0.9010563710950359 and parameters: {'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.05426759384610466, 'min_child_weight': 3, 'gamma': 2.3059289643916907, 'subsample': 0.9272561934172461, 'colsample_bytree': 0.9310142185134749, 'scale_pos_weight': 0.972448077719597}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:22:00,058] Trial 96 finished with value: 0.901416840158299 and parameters: {'n_estimators': 344, 'max_depth': 4, 'learning_rate': 0.08581869947658886, 'min_child_weight': 6, 'gamma': 1.0112686640185247, 'subsample': 0.8916427984307387, 'colsample_bytree': 0.9148131666122392, 'scale_pos_weight': 0.9445498425691353}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:22:01,157] Trial 97 finished with value: 0.9013943472823691 and parameters: {'n_estimators': 357, 'max_depth': 4, 'learning_rate': 0.09238551673331617, 'min_child_weight': 6, 'gamma': 1.2029933448344063, 'subsample': 0.9090199823871682, 'colsample_bytree': 0.8766825756063781, 'scale_pos_weight': 0.9989678776885087}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:22:02,395] Trial 98 finished with value: 0.9015997321896151 and parameters: {'n_estimators': 308, 'max_depth': 5, 'learning_rate': 0.039124349732223125, 'min_child_weight': 8, 'gamma': 0.8413912182727132, 'subsample': 0.8709896683002324, 'colsample_bytree': 0.9840145014842953, 'scale_pos_weight': 0.8860904410804101}. Best is trial 84 with value: 0.9018574284282022.
# [I 2025-04-10 08:22:03,434] Trial 99 finished with value: 0.8988537741733887 and parameters: {'n_estimators': 238, 'max_depth': 5, 'learning_rate': 0.027360130705235935, 'min_child_weight': 8, 'gamma': 0.8127950109217643, 'subsample': 0.845791498558584, 'colsample_bytree': 0.9860590796344939, 'scale_pos_weight': 0.8925233083859014}. Best is trial 84 with value: 0.9018574284282022.
# ✅ Best trial:
# AUC: 0.9018574284282022
# Params: {'n_estimators': 285, 'max_depth': 4, 'learning_rate': 0.08159743695042095, 'min_child_weight': 4, 'gamma': 1.2449394970977086, 'subsample': 0.8915439147949505, 'colsample_bytree': 0.9141412503037608, 'scale_pos_weight': 0.5843248205910467}

# %%
# trial들을 value 기준으로 정렬
sorted_trials = sorted(study.trials, key=lambda x: x.value, reverse=True)

# 상위 5개 출력
for i, trial in enumerate(sorted_trials[:5], 1):
    print(f"🔹 {i}등 Trial")
    print(f"  AUC: {trial.value}")
    print(f"  Params: {trial.params}\n")
# Out:
# 🔹 1등 Trial
#   AUC: 0.9018574284282022
#   Params: {'n_estimators': 285, 'max_depth': 4, 'learning_rate': 0.08159743695042095, 'min_child_weight': 4, 'gamma': 1.2449394970977086, 'subsample': 0.8915439147949505, 'colsample_bytree': 0.9141412503037608, 'scale_pos_weight': 0.5843248205910467}
#
# 🔹 2등 Trial
#   AUC: 0.9017685335258229
#   Params: {'n_estimators': 273, 'max_depth': 4, 'learning_rate': 0.07675471539146558, 'min_child_weight': 4, 'gamma': 1.2281977200793799, 'subsample': 0.8713934219411413, 'colsample_bytree': 0.9399599378392961, 'scale_pos_weight': 0.9751019184344335}
#
# 🔹 3등 Trial
#   AUC: 0.9017352366332195
#   Params: {'n_estimators': 195, 'max_depth': 4, 'learning_rate': 0.09563940358400486, 'min_child_weight': 14, 'gamma': 1.242268669141998, 'subsample': 0.8881746398775934, 'colsample_bytree': 0.9204006284324615, 'scale_pos_weight': 0.6308914507048188}
#
# 🔹 4등 Trial
#   AUC: 0.901733509970344
#   Params: {'n_estimators': 421, 'max_depth': 3, 'learning_rate': 0.1056657294942845, 'min_child_weight': 11, 'gamma': 1.537445767391795, 'subsample': 0.8931164133098327, 'colsample_bytree': 0.9290710442530649, 'scale_pos_weight': 0.6659544711836847}
#
# 🔹 5등 Trial
#   AUC: 0.9017176953625633
#   Params: {'n_estimators': 337, 'max_depth': 4, 'learning_rate': 0.09053755944554247, 'min_child_weight': 6, 'gamma': 1.692728726249683, 'subsample': 0.8818022525877556, 'colsample_bytree': 0.8830792897746043, 'scale_pos_weight': 0.9506109879562626}

# %%
params_1={
    'n_estimators': 285,
    'max_depth': 4,
    'learning_rate': 0.08159743695042095,
    'min_child_weight': 4,
    'gamma': 1.2449394970977086,
    'subsample': 0.8915439147949505,
    'colsample_bytree': 0.9141412503037608,
    'scale_pos_weight': 0.5843248205910467
}
params_2 = {
    'n_estimators': 273,
    'max_depth': 4,
    'learning_rate': 0.07675471539146558,
    'min_child_weight': 4,
    'gamma': 1.2281977200793799,
    'subsample': 0.8713934219411413,
    'colsample_bytree': 0.9399599378392961,
    'scale_pos_weight': 0.9751019184344335
}
params_3={
    'n_estimators': 195,
    'max_depth': 4,
    'learning_rate': 0.09563940358400486,
    'min_child_weight': 14,
    'gamma': 1.242268669141998,
    'subsample': 0.8881746398775934,
    'colsample_bytree': 0.9204006284324615,
    'scale_pos_weight': 0.6308914507048188
}
params_4={
    'n_estimators': 421,
    'max_depth': 3,
    'learning_rate': 0.1056657294942845,
    'min_child_weight': 11,
    'gamma': 1.537445767391795,
    'subsample': 0.8931164133098327,
    'colsample_bytree': 0.9290710442530649,
    'scale_pos_weight': 0.6659544711836847
}
params_5={
    'n_estimators': 337,
    'max_depth': 4,
    'learning_rate': 0.09053755944554247,
    'min_child_weight': 6,
    'gamma': 1.692728726249683,
    'subsample': 0.8818022525877556,
    'colsample_bytree': 0.8830792897746043,
    'scale_pos_weight': 0.9506109879562626
}

# %%
# optuna n_trials=100
xgb_5=XGBClassifier(params_5)

results_5=evaluate_xgb_model(params_5, X_trainval, y_trainval, X_test, y_test)

save_model_and_results(xgb_5, results_5, "/content/xgb_5(50).pkl")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:723: FutureWarning: Pass `objective` as keyword args.
#   warnings.warn(msg, FutureWarning)
# 📄 HPT 모델 성능 (5-Fold 평균 기반)
# Class 0 - Precision: 0.6304, Recall: 0.3287, F1: 0.4320
# Class 1 - Precision: 0.9120, Recall: 0.9730, F1: 0.9415
# Macro Avg     - Precision: 0.7712, Recall: 0.6509, F1: 0.6867
# Weighted Avg  - Precision: 0.8775, Recall: 0.8940, F1: 0.8790
# ROC AUC 평균: 0.9019
#
# 📊 HPT 모델 성능 (Test Set)
#               precision    recall  f1-score   support
#
#            0       0.61      0.33      0.43      1028
#            1       0.91      0.97      0.94      7353
#
#     accuracy                           0.89      8381
#    macro avg       0.76      0.65      0.69      8381
# weighted avg       0.88      0.89      0.88      8381
#
# ROC AUC Score: 0.9026
# '/content/xgb_5(50).pkl'

# %%
# Objective 함수 (2차 튜닝)
def objective_2nd(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 287, 387),  # ±50
        'max_depth': trial.suggest_int('max_depth', 3, 5),
        'learning_rate': trial.suggest_float('learning_rate', 0.060, 0.120, log=True),
        'min_child_weight': trial.suggest_int('min_child_weight', 4, 10),
        'gamma': trial.suggest_float('gamma', 1.2, 2.2),
        'subsample': trial.suggest_float('subsample', 0.84, 0.92),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.83, 0.93),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.85, 1.05),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)
    score = cross_val_score(model, X_trainval, y_trainval, cv=skf, scoring='roc_auc', n_jobs=-1)
    return np.mean(score)

# Study 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective_2nd, n_trials=100)

# 결과 출력
print("🎯 2차 Best trial:")
print("AUC:", study.best_value)
print("Params:", study.best_params)
# Out:
# [I 2025-04-10 09:09:23,433] A new study created in memory with name: no-name-485c2a36-4c02-42fc-bfcf-2902da3c7fca
# [I 2025-04-10 09:09:24,589] Trial 0 finished with value: 0.9014868679220029 and parameters: {'n_estimators': 355, 'max_depth': 5, 'learning_rate': 0.06171474173141282, 'min_child_weight': 10, 'gamma': 1.8220276021698438, 'subsample': 0.8537217441569678, 'colsample_bytree': 0.8671866991628727, 'scale_pos_weight': 0.9804981788989071}. Best is trial 0 with value: 0.9014868679220029.
# [I 2025-04-10 09:09:25,641] Trial 1 finished with value: 0.9010934295300677 and parameters: {'n_estimators': 323, 'max_depth': 4, 'learning_rate': 0.08670714144524305, 'min_child_weight': 6, 'gamma': 1.2869947080299151, 'subsample': 0.8583832408163823, 'colsample_bytree': 0.8905265247750229, 'scale_pos_weight': 0.9323128293557413}. Best is trial 0 with value: 0.9014868679220029.
# [I 2025-04-10 09:09:26,731] Trial 2 finished with value: 0.9016055876770057 and parameters: {'n_estimators': 372, 'max_depth': 3, 'learning_rate': 0.06704039206270024, 'min_child_weight': 10, 'gamma': 1.2169306865324478, 'subsample': 0.9128346410110578, 'colsample_bytree': 0.8688809561677823, 'scale_pos_weight': 1.031587643045521}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:27,832] Trial 3 finished with value: 0.9012997489584299 and parameters: {'n_estimators': 380, 'max_depth': 5, 'learning_rate': 0.06975452762828523, 'min_child_weight': 9, 'gamma': 1.9789311484889174, 'subsample': 0.8783185309560506, 'colsample_bytree': 0.8745917363280096, 'scale_pos_weight': 0.8504175465902312}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:28,915] Trial 4 finished with value: 0.9015483633579476 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.07155998873438901, 'min_child_weight': 8, 'gamma': 1.6143516665980313, 'subsample': 0.8667343553423974, 'colsample_bytree': 0.8862752368462506, 'scale_pos_weight': 0.9041328118617442}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:29,941] Trial 5 finished with value: 0.9003578429420427 and parameters: {'n_estimators': 317, 'max_depth': 5, 'learning_rate': 0.09371993166455664, 'min_child_weight': 4, 'gamma': 1.2707770177267799, 'subsample': 0.882399647835697, 'colsample_bytree': 0.9091271926051048, 'scale_pos_weight': 0.8532807365445269}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:31,045] Trial 6 finished with value: 0.9012518070996606 and parameters: {'n_estimators': 340, 'max_depth': 5, 'learning_rate': 0.08892504379447037, 'min_child_weight': 6, 'gamma': 1.815976282744635, 'subsample': 0.8696761396835886, 'colsample_bytree': 0.9266009445428536, 'scale_pos_weight': 0.9045358097949532}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:32,205] Trial 7 finished with value: 0.9007380797946274 and parameters: {'n_estimators': 354, 'max_depth': 3, 'learning_rate': 0.0694497958474321, 'min_child_weight': 7, 'gamma': 1.9501659483580382, 'subsample': 0.8730144163880204, 'colsample_bytree': 0.8898372223912138, 'scale_pos_weight': 0.8943974746991149}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:33,145] Trial 8 finished with value: 0.9012286654300894 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.08019474440095982, 'min_child_weight': 5, 'gamma': 1.9683240988807538, 'subsample': 0.8601943442426921, 'colsample_bytree': 0.8937544965447732, 'scale_pos_weight': 0.8955461093203855}. Best is trial 2 with value: 0.9016055876770057.
# [I 2025-04-10 09:09:34,134] Trial 9 finished with value: 0.9016795125876692 and parameters: {'n_estimators': 317, 'max_depth': 5, 'learning_rate': 0.07935616554744797, 'min_child_weight': 4, 'gamma': 2.123679447624651, 'subsample': 0.8763495981483919, 'colsample_bytree': 0.9293111398323802, 'scale_pos_weight': 0.9250518157254525}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:35,072] Trial 10 finished with value: 0.901338048845384 and parameters: {'n_estimators': 289, 'max_depth': 4, 'learning_rate': 0.11254424196705422, 'min_child_weight': 4, 'gamma': 2.1264422019748186, 'subsample': 0.9009180510770687, 'colsample_bytree': 0.8344557371969824, 'scale_pos_weight': 0.981900035406841}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:36,254] Trial 11 finished with value: 0.901078239757249 and parameters: {'n_estimators': 386, 'max_depth': 3, 'learning_rate': 0.06268777791707916, 'min_child_weight': 10, 'gamma': 1.4731466581976775, 'subsample': 0.9189786735561982, 'colsample_bytree': 0.8540219858259614, 'scale_pos_weight': 1.0217835756323657}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:37,223] Trial 12 finished with value: 0.9010760725621066 and parameters: {'n_estimators': 320, 'max_depth': 4, 'learning_rate': 0.07787729734446598, 'min_child_weight': 8, 'gamma': 2.1786950851856353, 'subsample': 0.894450694904991, 'colsample_bytree': 0.8534170101491199, 'scale_pos_weight': 1.0440857137470847}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:38,241] Trial 13 finished with value: 0.9015454683421273 and parameters: {'n_estimators': 366, 'max_depth': 3, 'learning_rate': 0.10507832319327709, 'min_child_weight': 8, 'gamma': 1.4931747248225686, 'subsample': 0.9124936853948606, 'colsample_bytree': 0.9263221055580535, 'scale_pos_weight': 0.953856477691112}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:39,379] Trial 14 finished with value: 0.9012267502585634 and parameters: {'n_estimators': 332, 'max_depth': 4, 'learning_rate': 0.07549555857289161, 'min_child_weight': 6, 'gamma': 1.202777433546331, 'subsample': 0.8453018239985401, 'colsample_bytree': 0.9101173716222966, 'scale_pos_weight': 0.9997367710150945}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:40,559] Trial 15 finished with value: 0.9012106094048313 and parameters: {'n_estimators': 373, 'max_depth': 3, 'learning_rate': 0.06574478526770644, 'min_child_weight': 5, 'gamma': 1.456263858928763, 'subsample': 0.8891808161923476, 'colsample_bytree': 0.8605650019705993, 'scale_pos_weight': 0.9462889447187635}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:41,556] Trial 16 finished with value: 0.901247614330126 and parameters: {'n_estimators': 305, 'max_depth': 5, 'learning_rate': 0.09617628435913733, 'min_child_weight': 9, 'gamma': 1.668496348651126, 'subsample': 0.9036443254952286, 'colsample_bytree': 0.8402281034472958, 'scale_pos_weight': 1.0375964923540584}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:42,634] Trial 17 finished with value: 0.9016363613422353 and parameters: {'n_estimators': 338, 'max_depth': 4, 'learning_rate': 0.08043257940595538, 'min_child_weight': 7, 'gamma': 1.8004741032258065, 'subsample': 0.885251032648922, 'colsample_bytree': 0.9060047741559459, 'scale_pos_weight': 1.0029733405793686}. Best is trial 9 with value: 0.9016795125876692.
# [I 2025-04-10 09:09:43,817] Trial 18 finished with value: 0.9018951772242529 and parameters: {'n_estimators': 340, 'max_depth': 4, 'learning_rate': 0.0819702343464689, 'min_child_weight': 5, 'gamma': 1.809783462760216, 'subsample': 0.8865942447541951, 'colsample_bytree': 0.9093384622689645, 'scale_pos_weight': 1.0023319075204367}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:44,765] Trial 19 finished with value: 0.9017300049524477 and parameters: {'n_estimators': 309, 'max_depth': 5, 'learning_rate': 0.10061639728305558, 'min_child_weight': 5, 'gamma': 2.0884683664923025, 'subsample': 0.8949817605774765, 'colsample_bytree': 0.9176032791913473, 'scale_pos_weight': 0.9701055458454547}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:45,652] Trial 20 finished with value: 0.9014668981707018 and parameters: {'n_estimators': 304, 'max_depth': 4, 'learning_rate': 0.1179417349551636, 'min_child_weight': 5, 'gamma': 2.0440775527778148, 'subsample': 0.894846715694043, 'colsample_bytree': 0.9166536786049558, 'scale_pos_weight': 0.969562895427391}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:46,588] Trial 21 finished with value: 0.901570650172653 and parameters: {'n_estimators': 311, 'max_depth': 5, 'learning_rate': 0.09986609216069693, 'min_child_weight': 4, 'gamma': 2.0810170429165984, 'subsample': 0.8773470278580432, 'colsample_bytree': 0.9188448335624562, 'scale_pos_weight': 0.9243341601639505}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:47,616] Trial 22 finished with value: 0.901426893758314 and parameters: {'n_estimators': 330, 'max_depth': 5, 'learning_rate': 0.08439370354575296, 'min_child_weight': 5, 'gamma': 1.872137515788224, 'subsample': 0.8918060502475229, 'colsample_bytree': 0.9005289550441398, 'scale_pos_weight': 0.9981882900235325}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:48,535] Trial 23 finished with value: 0.9014553512241607 and parameters: {'n_estimators': 291, 'max_depth': 5, 'learning_rate': 0.09174674016034695, 'min_child_weight': 4, 'gamma': 2.16825372969786, 'subsample': 0.9046076453265867, 'colsample_bytree': 0.919666943983716, 'scale_pos_weight': 0.9612611015065479}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:49,501] Trial 24 finished with value: 0.9012582739376261 and parameters: {'n_estimators': 343, 'max_depth': 5, 'learning_rate': 0.10284759812581537, 'min_child_weight': 5, 'gamma': 2.0575627083225942, 'subsample': 0.8883134943705184, 'colsample_bytree': 0.9286100761929986, 'scale_pos_weight': 0.9340841361232617}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:50,499] Trial 25 finished with value: 0.9014529015131059 and parameters: {'n_estimators': 329, 'max_depth': 4, 'learning_rate': 0.08376886884568928, 'min_child_weight': 6, 'gamma': 1.9079950947137925, 'subsample': 0.8996403814184033, 'colsample_bytree': 0.9007555511548844, 'scale_pos_weight': 1.0105893519743505}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:51,519] Trial 26 finished with value: 0.9018941965426018 and parameters: {'n_estimators': 311, 'max_depth': 4, 'learning_rate': 0.07635576004047448, 'min_child_weight': 4, 'gamma': 1.7623723203271415, 'subsample': 0.8759381455543527, 'colsample_bytree': 0.9133297471012485, 'scale_pos_weight': 0.9817951847743885}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:52,538] Trial 27 finished with value: 0.9016640274248351 and parameters: {'n_estimators': 298, 'max_depth': 4, 'learning_rate': 0.07421147818439722, 'min_child_weight': 5, 'gamma': 1.7190489111260825, 'subsample': 0.8828346971108804, 'colsample_bytree': 0.916324731972756, 'scale_pos_weight': 0.9834322180145718}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:53,505] Trial 28 finished with value: 0.9009351407130046 and parameters: {'n_estimators': 310, 'max_depth': 4, 'learning_rate': 0.11062143506805511, 'min_child_weight': 7, 'gamma': 1.5722874803201703, 'subsample': 0.8642902223678203, 'colsample_bytree': 0.8999597596987717, 'scale_pos_weight': 1.017991202945013}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:54,559] Trial 29 finished with value: 0.9018842818437554 and parameters: {'n_estimators': 348, 'max_depth': 4, 'learning_rate': 0.09760827117817085, 'min_child_weight': 4, 'gamma': 1.8184545559387628, 'subsample': 0.8724526530861989, 'colsample_bytree': 0.8839099997322225, 'scale_pos_weight': 0.9727297803087873}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:55,739] Trial 30 finished with value: 0.9015971520222184 and parameters: {'n_estimators': 347, 'max_depth': 4, 'learning_rate': 0.09002977160758542, 'min_child_weight': 4, 'gamma': 1.7240263358014507, 'subsample': 0.851424731581599, 'colsample_bytree': 0.8833111641782146, 'scale_pos_weight': 0.9918223077121399}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:56,789] Trial 31 finished with value: 0.9014430018262305 and parameters: {'n_estimators': 362, 'max_depth': 4, 'learning_rate': 0.09797557707215916, 'min_child_weight': 4, 'gamma': 1.7746668057808388, 'subsample': 0.8851933228188162, 'colsample_bytree': 0.9110746054104027, 'scale_pos_weight': 0.9735575529236411}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:57,777] Trial 32 finished with value: 0.901634127783025 and parameters: {'n_estimators': 347, 'max_depth': 4, 'learning_rate': 0.10482254376346357, 'min_child_weight': 5, 'gamma': 1.9064240098445377, 'subsample': 0.8722634423482002, 'colsample_bytree': 0.8790949102226993, 'scale_pos_weight': 0.9649968598429477}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:58,806] Trial 33 finished with value: 0.9013275187249592 and parameters: {'n_estimators': 323, 'max_depth': 4, 'learning_rate': 0.08709981769226907, 'min_child_weight': 6, 'gamma': 1.6294119527901505, 'subsample': 0.8625315465024066, 'colsample_bytree': 0.8959337119538476, 'scale_pos_weight': 0.9874419740207746}. Best is trial 18 with value: 0.9018951772242529.
# [I 2025-04-10 09:09:59,884] Trial 34 finished with value: 0.9019031901878225 and parameters: {'n_estimators': 360, 'max_depth': 4, 'learning_rate': 0.08420993116360205, 'min_child_weight': 4, 'gamma': 1.864059192676658, 'subsample': 0.8759485899690264, 'colsample_bytree': 0.8733106950055982, 'scale_pos_weight': 0.9438943749818433}. Best is trial 34 with value: 0.9019031901878225.
# [I 2025-04-10 09:10:00,955] Trial 35 finished with value: 0.90124330947693 and parameters: {'n_estimators': 358, 'max_depth': 4, 'learning_rate': 0.08189525023290238, 'min_child_weight': 4, 'gamma': 1.8550156397659567, 'subsample': 0.8554793677256258, 'colsample_bytree': 0.8687878656413628, 'scale_pos_weight': 0.9436620567569933}. Best is trial 34 with value: 0.9019031901878225.
# [I 2025-04-10 09:10:02,058] Trial 36 finished with value: 0.9015079697402977 and parameters: {'n_estimators': 369, 'max_depth': 4, 'learning_rate': 0.07600617418280332, 'min_child_weight': 4, 'gamma': 1.755910396468008, 'subsample': 0.8680084500182272, 'colsample_bytree': 0.8765885903763525, 'scale_pos_weight': 0.9560171093186526}. Best is trial 34 with value: 0.9019031901878225.
# [I 2025-04-10 09:10:03,148] Trial 37 finished with value: 0.901498921691239 and parameters: {'n_estimators': 359, 'max_depth': 4, 'learning_rate': 0.0729643126641941, 'min_child_weight': 4, 'gamma': 1.659818315113562, 'subsample': 0.8784769015589017, 'colsample_bytree': 0.8624738872687219, 'scale_pos_weight': 1.0265134409548458}. Best is trial 34 with value: 0.9019031901878225.
# [I 2025-04-10 09:10:04,218] Trial 38 finished with value: 0.9019473166354693 and parameters: {'n_estimators': 349, 'max_depth': 4, 'learning_rate': 0.08623486667008952, 'min_child_weight': 5, 'gamma': 1.5646162778661707, 'subsample': 0.8718620060407601, 'colsample_bytree': 0.871407684824421, 'scale_pos_weight': 0.9370579241954289}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:05,217] Trial 39 finished with value: 0.9015869441718799 and parameters: {'n_estimators': 334, 'max_depth': 3, 'learning_rate': 0.08647574896911707, 'min_child_weight': 6, 'gamma': 1.5273585156045597, 'subsample': 0.8809333277798739, 'colsample_bytree': 0.8735629037279007, 'scale_pos_weight': 0.9123532560632083}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:06,383] Trial 40 finished with value: 0.9017634001315749 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.06869145667358852, 'min_child_weight': 5, 'gamma': 1.3890769198619328, 'subsample': 0.8747566422484542, 'colsample_bytree': 0.8893240058710663, 'scale_pos_weight': 0.9424093474197436}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:07,488] Trial 41 finished with value: 0.9016762704033663 and parameters: {'n_estimators': 348, 'max_depth': 4, 'learning_rate': 0.0941790650452499, 'min_child_weight': 4, 'gamma': 1.8410961704912627, 'subsample': 0.8703842214885684, 'colsample_bytree': 0.8828973741960765, 'scale_pos_weight': 0.8706255828331123}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:08,510] Trial 42 finished with value: 0.9015080840574013 and parameters: {'n_estimators': 341, 'max_depth': 4, 'learning_rate': 0.08353911796182177, 'min_child_weight': 4, 'gamma': 1.9934194028765106, 'subsample': 0.8658699775144166, 'colsample_bytree': 0.8625494671704637, 'scale_pos_weight': 0.9357326431517996}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:09,572] Trial 43 finished with value: 0.9017242450727696 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.07780694635147485, 'min_child_weight': 5, 'gamma': 1.7548755592298628, 'subsample': 0.8730024566904344, 'colsample_bytree': 0.8713570047901688, 'scale_pos_weight': 0.913638262053652}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:10,593] Trial 44 finished with value: 0.9013618344793709 and parameters: {'n_estimators': 326, 'max_depth': 4, 'learning_rate': 0.08925532051089234, 'min_child_weight': 6, 'gamma': 1.5803661015654673, 'subsample': 0.8813257946314248, 'colsample_bytree': 0.8480915328736369, 'scale_pos_weight': 0.976810897307521}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:11,674] Trial 45 finished with value: 0.9011890911965212 and parameters: {'n_estimators': 344, 'max_depth': 4, 'learning_rate': 0.07093381656243468, 'min_child_weight': 4, 'gamma': 1.9188498318520284, 'subsample': 0.8581622276630805, 'colsample_bytree': 0.8656424955384685, 'scale_pos_weight': 0.9573369835763217}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:12,756] Trial 46 finished with value: 0.9014613239888941 and parameters: {'n_estimators': 375, 'max_depth': 4, 'learning_rate': 0.09257723788082717, 'min_child_weight': 5, 'gamma': 1.806949057991191, 'subsample': 0.8684695873060775, 'colsample_bytree': 0.8853488178568444, 'scale_pos_weight': 0.9277073867458566}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:13,765] Trial 47 finished with value: 0.9009780853432716 and parameters: {'n_estimators': 336, 'max_depth': 3, 'learning_rate': 0.08159226648828881, 'min_child_weight': 4, 'gamma': 1.678421980942087, 'subsample': 0.8756077507170249, 'colsample_bytree': 0.8575223634249238, 'scale_pos_weight': 1.0109879377529227}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:14,867] Trial 48 finished with value: 0.9016064450248589 and parameters: {'n_estimators': 365, 'max_depth': 4, 'learning_rate': 0.08663812420923227, 'min_child_weight': 9, 'gamma': 1.4110082377867075, 'subsample': 0.8854243231050485, 'colsample_bytree': 0.8934784955259395, 'scale_pos_weight': 0.9899932667262836}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:15,909] Trial 49 finished with value: 0.9019039173390626 and parameters: {'n_estimators': 357, 'max_depth': 4, 'learning_rate': 0.0778635345786514, 'min_child_weight': 5, 'gamma': 2.0044407024589193, 'subsample': 0.8786650244998224, 'colsample_bytree': 0.9054758459581934, 'scale_pos_weight': 0.9514884589948901}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:16,969] Trial 50 finished with value: 0.9018404040507549 and parameters: {'n_estimators': 357, 'max_depth': 4, 'learning_rate': 0.07734876178261832, 'min_child_weight': 6, 'gamma': 2.016159976142607, 'subsample': 0.8789458723074521, 'colsample_bytree': 0.9057033132527845, 'scale_pos_weight': 0.8868746447988831}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:18,051] Trial 51 finished with value: 0.901843397322939 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.07968078526288092, 'min_child_weight': 5, 'gamma': 1.961473064448719, 'subsample': 0.8709324758976403, 'colsample_bytree': 0.922653878758437, 'scale_pos_weight': 0.9444200358093028}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:19,179] Trial 52 finished with value: 0.9018413887773988 and parameters: {'n_estimators': 363, 'max_depth': 4, 'learning_rate': 0.07323550498147367, 'min_child_weight': 4, 'gamma': 1.8775083196226132, 'subsample': 0.8747738813063647, 'colsample_bytree': 0.913828282287383, 'scale_pos_weight': 0.9530168901250923}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:20,242] Trial 53 finished with value: 0.901753722408013 and parameters: {'n_estimators': 340, 'max_depth': 4, 'learning_rate': 0.0756198482839268, 'min_child_weight': 5, 'gamma': 1.795065197755172, 'subsample': 0.8883068809241486, 'colsample_bytree': 0.8791928214331982, 'scale_pos_weight': 0.9641212538008277}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:21,307] Trial 54 finished with value: 0.9014669767062964 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.08217745751337369, 'min_child_weight': 4, 'gamma': 1.830489301590266, 'subsample': 0.8832748770606952, 'colsample_bytree': 0.9069371846874287, 'scale_pos_weight': 0.9779221045912414}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:22,511] Trial 55 finished with value: 0.9016198390062922 and parameters: {'n_estimators': 369, 'max_depth': 4, 'learning_rate': 0.06025359164770931, 'min_child_weight': 5, 'gamma': 1.7168900238960287, 'subsample': 0.8626398199071322, 'colsample_bytree': 0.9237744932616393, 'scale_pos_weight': 0.9226713941271996}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:23,584] Trial 56 finished with value: 0.901664902772704 and parameters: {'n_estimators': 360, 'max_depth': 4, 'learning_rate': 0.07904205762853013, 'min_child_weight': 7, 'gamma': 1.9300626808820984, 'subsample': 0.8783248295879738, 'colsample_bytree': 0.8887601051560744, 'scale_pos_weight': 1.0070191199440437}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:24,664] Trial 57 finished with value: 0.9009405957255279 and parameters: {'n_estimators': 344, 'max_depth': 3, 'learning_rate': 0.06654787630590198, 'min_child_weight': 4, 'gamma': 1.6329814357946681, 'subsample': 0.8667518837194376, 'colsample_bytree': 0.89742665225224, 'scale_pos_weight': 0.9390785665610198}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:25,817] Trial 58 finished with value: 0.90125605623206 and parameters: {'n_estimators': 378, 'max_depth': 4, 'learning_rate': 0.08557054566854652, 'min_child_weight': 10, 'gamma': 1.33408181931543, 'subsample': 0.8755927759697519, 'colsample_bytree': 0.9033335955555988, 'scale_pos_weight': 0.9505912093248058}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:26,799] Trial 59 finished with value: 0.9013686769322918 and parameters: {'n_estimators': 336, 'max_depth': 4, 'learning_rate': 0.09120460460063923, 'min_child_weight': 5, 'gamma': 1.882439869485646, 'subsample': 0.8892822474842793, 'colsample_bytree': 0.8749096958707164, 'scale_pos_weight': 0.9962291788620898}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:27,916] Trial 60 finished with value: 0.901550469703667 and parameters: {'n_estimators': 383, 'max_depth': 4, 'learning_rate': 0.0945665138954814, 'min_child_weight': 8, 'gamma': 1.5832031564871114, 'subsample': 0.8711975810445445, 'colsample_bytree': 0.9131737832928042, 'scale_pos_weight': 0.9676629504763116}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:28,979] Trial 61 finished with value: 0.9018133842016516 and parameters: {'n_estimators': 351, 'max_depth': 4, 'learning_rate': 0.08116828696632644, 'min_child_weight': 5, 'gamma': 1.9792362852044691, 'subsample': 0.8726625496305543, 'colsample_bytree': 0.90841553128008, 'scale_pos_weight': 0.9491266124953649}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:30,148] Trial 62 finished with value: 0.9016616995923096 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.07882946140497082, 'min_child_weight': 5, 'gamma': 1.9663135747282678, 'subsample': 0.8601894960969408, 'colsample_bytree': 0.9235128547367961, 'scale_pos_weight': 0.9155923939613624}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:31,249] Trial 63 finished with value: 0.9015511591309855 and parameters: {'n_estimators': 348, 'max_depth': 4, 'learning_rate': 0.08779826900036554, 'min_child_weight': 6, 'gamma': 2.0263120649874806, 'subsample': 0.8702999628592822, 'colsample_bytree': 0.9228655600419835, 'scale_pos_weight': 0.930109506381251}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:32,312] Trial 64 finished with value: 0.9015549123305927 and parameters: {'n_estimators': 343, 'max_depth': 4, 'learning_rate': 0.08386518912115679, 'min_child_weight': 5, 'gamma': 1.9402228597413627, 'subsample': 0.8401158123001362, 'colsample_bytree': 0.9199195570865271, 'scale_pos_weight': 0.9585148342008124}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:33,385] Trial 65 finished with value: 0.901585385235925 and parameters: {'n_estimators': 356, 'max_depth': 4, 'learning_rate': 0.07672394095734274, 'min_child_weight': 4, 'gamma': 1.7501413228209108, 'subsample': 0.8808052741412563, 'colsample_bytree': 0.9133738823652605, 'scale_pos_weight': 0.9473033623603839}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:34,478] Trial 66 finished with value: 0.9015615893771785 and parameters: {'n_estimators': 355, 'max_depth': 4, 'learning_rate': 0.07423994229917684, 'min_child_weight': 6, 'gamma': 1.8300329923261005, 'subsample': 0.8653443902650163, 'colsample_bytree': 0.8676232749802898, 'scale_pos_weight': 0.9831599547812299}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:35,566] Trial 67 finished with value: 0.9015801262076849 and parameters: {'n_estimators': 361, 'max_depth': 4, 'learning_rate': 0.08024172501908698, 'min_child_weight': 5, 'gamma': 1.7832018454820853, 'subsample': 0.8835295814083307, 'colsample_bytree': 0.9030795790866262, 'scale_pos_weight': 0.970262514568616}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:36,629] Trial 68 finished with value: 0.9011681220424738 and parameters: {'n_estimators': 365, 'max_depth': 4, 'learning_rate': 0.07138405341455421, 'min_child_weight': 4, 'gamma': 2.1204426321193286, 'subsample': 0.8923156894861226, 'colsample_bytree': 0.9299666432796458, 'scale_pos_weight': 0.9400400237540817}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:37,581] Trial 69 finished with value: 0.9015194918780386 and parameters: {'n_estimators': 314, 'max_depth': 4, 'learning_rate': 0.11106024554217395, 'min_child_weight': 5, 'gamma': 1.882310042568975, 'subsample': 0.8773360114869134, 'colsample_bytree': 0.8925456475268714, 'scale_pos_weight': 0.9048746607315935}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:38,594] Trial 70 finished with value: 0.9012410263570635 and parameters: {'n_estimators': 332, 'max_depth': 5, 'learning_rate': 0.08282000127710204, 'min_child_weight': 4, 'gamma': 2.004198586456347, 'subsample': 0.8735520381905587, 'colsample_bytree': 0.8304392923652559, 'scale_pos_weight': 0.9337670553611445}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:39,682] Trial 71 finished with value: 0.9016546467882194 and parameters: {'n_estimators': 363, 'max_depth': 4, 'learning_rate': 0.07393149729070694, 'min_child_weight': 4, 'gamma': 1.8627161779235588, 'subsample': 0.869257165441967, 'colsample_bytree': 0.9132398721547405, 'scale_pos_weight': 0.9532289921883619}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:40,786] Trial 72 finished with value: 0.901421981082813 and parameters: {'n_estimators': 369, 'max_depth': 4, 'learning_rate': 0.07271453661084246, 'min_child_weight': 4, 'gamma': 1.904436919615441, 'subsample': 0.875540757177999, 'colsample_bytree': 0.9163860369067607, 'scale_pos_weight': 0.9629102048886237}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:41,878] Trial 73 finished with value: 0.9015554929689774 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.06948210754806369, 'min_child_weight': 4, 'gamma': 1.9466491712754397, 'subsample': 0.8862991258573415, 'colsample_bytree': 0.9106538505762237, 'scale_pos_weight': 0.9465038217534173}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:43,012] Trial 74 finished with value: 0.901744558154571 and parameters: {'n_estimators': 346, 'max_depth': 4, 'learning_rate': 0.07928310578516419, 'min_child_weight': 4, 'gamma': 1.6966130183571664, 'subsample': 0.8738188313532472, 'colsample_bytree': 0.925647485385654, 'scale_pos_weight': 0.9756646465104778}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:44,034] Trial 75 finished with value: 0.9014733625498487 and parameters: {'n_estimators': 295, 'max_depth': 4, 'learning_rate': 0.06489075508161597, 'min_child_weight': 5, 'gamma': 1.8927782098582202, 'subsample': 0.8796121289234579, 'colsample_bytree': 0.8707329678224036, 'scale_pos_weight': 0.9210891385325163}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:45,047] Trial 76 finished with value: 0.9016890244448653 and parameters: {'n_estimators': 339, 'max_depth': 4, 'learning_rate': 0.07556344873622763, 'min_child_weight': 4, 'gamma': 2.0574086876497972, 'subsample': 0.877172561233038, 'colsample_bytree': 0.9206373175019484, 'scale_pos_weight': 0.9522467069040993}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:46,039] Trial 77 finished with value: 0.9016773462873712 and parameters: {'n_estimators': 358, 'max_depth': 4, 'learning_rate': 0.11996678877930442, 'min_child_weight': 5, 'gamma': 1.8511810953225423, 'subsample': 0.8673495192801854, 'colsample_bytree': 0.9152668342243612, 'scale_pos_weight': 0.9379637363467895}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:46,991] Trial 78 finished with value: 0.9014745526197061 and parameters: {'n_estimators': 287, 'max_depth': 4, 'learning_rate': 0.08495579345044363, 'min_child_weight': 4, 'gamma': 1.772985872912234, 'subsample': 0.863247709555106, 'colsample_bytree': 0.8824542727032522, 'scale_pos_weight': 0.9600671873636927}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:48,106] Trial 79 finished with value: 0.901451113614263 and parameters: {'n_estimators': 353, 'max_depth': 4, 'learning_rate': 0.0683083093006385, 'min_child_weight': 6, 'gamma': 1.813329065345158, 'subsample': 0.8718238637681472, 'colsample_bytree': 0.9038820877428323, 'scale_pos_weight': 0.9856058491414377}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:49,182] Trial 80 finished with value: 0.9016303898985498 and parameters: {'n_estimators': 372, 'max_depth': 4, 'learning_rate': 0.0781839195068579, 'min_child_weight': 4, 'gamma': 1.9759254766973602, 'subsample': 0.8810384607348161, 'colsample_bytree': 0.8646929687305573, 'scale_pos_weight': 0.9925416160674202}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:50,255] Trial 81 finished with value: 0.9017824256223189 and parameters: {'n_estimators': 357, 'max_depth': 4, 'learning_rate': 0.07725323889706684, 'min_child_weight': 6, 'gamma': 1.7348626130816758, 'subsample': 0.8784488244534147, 'colsample_bytree': 0.905814525924281, 'scale_pos_weight': 0.8811361024325819}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:51,287] Trial 82 finished with value: 0.9015857901464269 and parameters: {'n_estimators': 363, 'max_depth': 4, 'learning_rate': 0.08008977857117336, 'min_child_weight': 6, 'gamma': 2.018990895714372, 'subsample': 0.8798187698882363, 'colsample_bytree': 0.9086149525461189, 'scale_pos_weight': 0.9712257916919321}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:52,385] Trial 83 finished with value: 0.9013913315536131 and parameters: {'n_estimators': 367, 'max_depth': 4, 'learning_rate': 0.07442960275573884, 'min_child_weight': 7, 'gamma': 2.0818535664581863, 'subsample': 0.8745727236986685, 'colsample_bytree': 0.8970659925549433, 'scale_pos_weight': 0.8947542522635007}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:53,466] Trial 84 finished with value: 0.9015745446541977 and parameters: {'n_estimators': 356, 'max_depth': 4, 'learning_rate': 0.07712811186717881, 'min_child_weight': 5, 'gamma': 1.9340103059537714, 'subsample': 0.869175520567712, 'colsample_bytree': 0.9006070757665796, 'scale_pos_weight': 0.8835657296800044}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:54,605] Trial 85 finished with value: 0.901516167666984 and parameters: {'n_estimators': 349, 'max_depth': 4, 'learning_rate': 0.08798000738619405, 'min_child_weight': 7, 'gamma': 1.526093033406797, 'subsample': 0.8832563019855819, 'colsample_bytree': 0.8769548800821045, 'scale_pos_weight': 1.0375041262688764}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:55,609] Trial 86 finished with value: 0.9018841442203861 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.107550214159738, 'min_child_weight': 5, 'gamma': 2.1104117023791282, 'subsample': 0.8766703551226419, 'colsample_bytree': 0.9181473875212395, 'scale_pos_weight': 1.0186184479533125}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:56,601] Trial 87 finished with value: 0.901434494937828 and parameters: {'n_estimators': 346, 'max_depth': 4, 'learning_rate': 0.10026664651066612, 'min_child_weight': 5, 'gamma': 2.1544733949266486, 'subsample': 0.8718102997332494, 'colsample_bytree': 0.9182836829608544, 'scale_pos_weight': 1.0162518821614028}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:57,836] Trial 88 finished with value: 0.9015951677458134 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.10659722360932021, 'min_child_weight': 5, 'gamma': 2.116521354671538, 'subsample': 0.8760687739612967, 'colsample_bytree': 0.9264053628397666, 'scale_pos_weight': 1.029783977452178}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:58,884] Trial 89 finished with value: 0.9014521169920112 and parameters: {'n_estimators': 360, 'max_depth': 4, 'learning_rate': 0.10893320631732561, 'min_child_weight': 4, 'gamma': 2.184533977805376, 'subsample': 0.8848217409920434, 'colsample_bytree': 0.922078470914363, 'scale_pos_weight': 1.0048462444792992}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:10:59,880] Trial 90 finished with value: 0.9014987211415697 and parameters: {'n_estimators': 345, 'max_depth': 4, 'learning_rate': 0.09772706772271574, 'min_child_weight': 5, 'gamma': 1.8684866924350725, 'subsample': 0.9166667193063632, 'colsample_bytree': 0.9116638201538538, 'scale_pos_weight': 1.0234848541147208}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:00,833] Trial 91 finished with value: 0.901686427773001 and parameters: {'n_estimators': 341, 'max_depth': 4, 'learning_rate': 0.11655405065129497, 'min_child_weight': 5, 'gamma': 2.0218158085674203, 'subsample': 0.8780146542198379, 'colsample_bytree': 0.9137960642422049, 'scale_pos_weight': 0.8554615409046942}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:01,836] Trial 92 finished with value: 0.9017729503928132 and parameters: {'n_estimators': 358, 'max_depth': 4, 'learning_rate': 0.1024305380216823, 'min_child_weight': 6, 'gamma': 2.057658045460115, 'subsample': 0.8871586097455685, 'colsample_bytree': 0.8715264986917826, 'scale_pos_weight': 1.0007260349695386}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:02,972] Trial 93 finished with value: 0.9016975830856173 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.07262383463585013, 'min_child_weight': 4, 'gamma': 1.818072615691902, 'subsample': 0.8741202747687452, 'colsample_bytree': 0.9065844120740972, 'scale_pos_weight': 1.0141289358281018}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:03,917] Trial 94 finished with value: 0.9015201874113001 and parameters: {'n_estimators': 305, 'max_depth': 4, 'learning_rate': 0.11408734458335253, 'min_child_weight': 5, 'gamma': 1.9619975164416759, 'subsample': 0.8705021848457504, 'colsample_bytree': 0.918190393144507, 'scale_pos_weight': 0.9966588068654788}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:04,960] Trial 95 finished with value: 0.9016206212134804 and parameters: {'n_estimators': 350, 'max_depth': 4, 'learning_rate': 0.08137095123905003, 'min_child_weight': 5, 'gamma': 2.096590758219686, 'subsample': 0.8815780286350101, 'colsample_bytree': 0.9092856653916909, 'scale_pos_weight': 0.9797088583930043}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:06,068] Trial 96 finished with value: 0.9015266405619411 and parameters: {'n_estimators': 362, 'max_depth': 4, 'learning_rate': 0.0764332062968431, 'min_child_weight': 4, 'gamma': 1.9141702813783983, 'subsample': 0.8914211261351318, 'colsample_bytree': 0.9159867749451832, 'scale_pos_weight': 0.9416909072055017}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:07,127] Trial 97 finished with value: 0.9016646244268431 and parameters: {'n_estimators': 348, 'max_depth': 4, 'learning_rate': 0.08567311208468881, 'min_child_weight': 6, 'gamma': 2.152747761164815, 'subsample': 0.8791277652780395, 'colsample_bytree': 0.904293373622455, 'scale_pos_weight': 0.9562218890931958}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:08,182] Trial 98 finished with value: 0.9016207061277928 and parameters: {'n_estimators': 341, 'max_depth': 4, 'learning_rate': 0.08282713961100571, 'min_child_weight': 4, 'gamma': 1.9953639856762186, 'subsample': 0.8767263872290939, 'colsample_bytree': 0.9111147565578737, 'scale_pos_weight': 0.967021206670298}. Best is trial 38 with value: 0.9019473166354693.
# [I 2025-04-10 09:11:09,360] Trial 99 finished with value: 0.9013640152752591 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.07037781309136465, 'min_child_weight': 5, 'gamma': 1.2571502908899839, 'subsample': 0.8673582813572174, 'colsample_bytree': 0.9215884267668204, 'scale_pos_weight': 0.9324499403991167}. Best is trial 38 with value: 0.9019473166354693.
# 🎯 2차 Best trial:
# AUC: 0.9019473166354693
# Params: {'n_estimators': 349, 'max_depth': 4, 'learning_rate': 0.08623486667008952, 'min_child_weight': 5, 'gamma': 1.5646162778661707, 'subsample': 0.8718620060407601, 'colsample_bytree': 0.871407684824421, 'scale_pos_weight': 0.9370579241954289}

# %%
study.best_params
# Out:
# {'n_estimators': 349,
#  'max_depth': 4,
#  'learning_rate': 0.08623486667008952,
#  'min_child_weight': 5,
#  'gamma': 1.5646162778661707,
#  'subsample': 0.8718620060407601,
#  'colsample_bytree': 0.871407684824421,
#  'scale_pos_weight': 0.9370579241954289}

# %%
xgb_52 = XGBClassifier(**study.best_params)

# 성능 평가
results_52 = evaluate_xgb_model(
    study.best_params,
    X_trainval,
    y_trainval,
    X_test,
    y_test
)

save_model_and_results(xgb_52, results_52, "/content/xgb_52(50).pkl")
# Out:
# 📄 HPT 모델 성능 (5-Fold 평균 기반)
# Class 0 - Precision: 0.6288, Recall: 0.3431, F1: 0.4437
# Class 1 - Precision: 0.9136, Recall: 0.9717, F1: 0.9418
# Macro Avg     - Precision: 0.7712, Recall: 0.6574, F1: 0.6927
# Weighted Avg  - Precision: 0.8787, Recall: 0.8945, F1: 0.8806
# ROC AUC 평균: 0.9014
#
# 📊 HPT 모델 성능 (Test Set)
#               precision    recall  f1-score   support
#
#            0       0.61      0.34      0.44      1028
#            1       0.91      0.97      0.94      7353
#
#     accuracy                           0.89      8381
#    macro avg       0.76      0.65      0.69      8381
# weighted avg       0.88      0.89      0.88      8381
#
# ROC AUC Score: 0.9032
# '/content/xgb_52(50).pkl'

# %%
with open('/content/xgb_base.pkl', 'rb') as f:
    data = pickle.load(f)
    scores = data['scores']

with open('/content/xgb_1-1.pkl', 'rb') as f:
    data1 = pickle.load(f)
    scores1 = data1['scores']

with open('/content/xgb_2-1.pkl', 'rb') as f:
    data2 = pickle.load(f)
    scores2 = data2['scores']

with open('/content/xgb_3-1.pkl', 'rb') as f:
    data3 = pickle.load(f)
    scores3 = data3['scores']

with open('/content/xgb_4-1.pkl', 'rb') as f:
    data4 = pickle.load(f)
    scores4 = data4['scores']

with open('/content/xgb_5-1.pkl', 'rb') as f:
    data5 = pickle.load(f)
    scores5 = data5['scores']

with open('/content/xgb_sv.pkl', 'rb') as f:
    data6 = pickle.load(f)
    scores_sv = data6['scores']

# with open('/content/xgb_sv135(50).pkl', 'rb') as f:
#     data7 = pickle.load(f)
#     scores135 = data7['scores']

# with open('/content/xgb_sv345(50).pkl', 'rb') as f:
#     data8 = pickle.load(f)
#     scores345 = data8['scores']

print(scores)
print(scores1)
print(scores2)
print(scores3)
print(scores4)
print(scores5)
print(scores_sv)
# Out:
# {'cv': {'class_0': {'precision': np.float64(0.581960848704254), 'recall': np.float64(0.3532743242484176), 'f1': np.float64(0.43948547725213016)}, 'class_1': {'precision': np.float64(0.8447719779802265), 'recall': np.float64(0.9327832892013384), 'f1': np.float64(0.8865907798880842)}, 'macro_avg': {'precision': np.float64(0.7133664133422403), 'recall': np.float64(0.6430288067248779), 'f1': np.float64(0.6630381285701072)}, 'weighted_avg': {'precision': np.float64(0.7897061514538855), 'recall': np.float64(0.8113609574208308), 'f1': np.float64(0.7929104890199398)}, 'roc_auc': np.float64(0.7933351859083697)}, 'test': {'classification_report': {'0': {'precision': 0.6114754098360655, 'recall': 0.36284046692607, 'f1-score': 0.4554334554334554, 'support': 1028.0}, '1': {'precision': 0.847603536528618, 'recall': 0.9389175257731959, 'f1-score': 0.8909268769870384, 'support': 3880.0}, 'accuracy': 0.8182559087204564, 'macro avg': {'precision': 0.7295394731823417, 'recall': 0.650878996349633, 'f1-score': 0.6731801662102469, 'support': 4908.0}, 'weighted avg': {'precision': 0.7981455670420768, 'recall': 0.8182559087204564, 'f1-score': 0.7997110584546253, 'support': 4908.0}}, 'roc_auc': np.float64(0.8036887259817882)}}
# {'cv': {'class_0': {'precision': np.float64(0.6126912675782826), 'recall': np.float64(0.37418056898238894), 'f1': np.float64(0.4645084076238458)}, 'class_1': {'precision': np.float64(0.8496128308124573), 'recall': np.float64(0.9371656669136286), 'f1': np.float64(0.8912395455418924)}, 'macro_avg': {'precision': np.float64(0.73115204919537), 'recall': np.float64(0.6556731179480088), 'f1': np.float64(0.6778739765828692)}, 'weighted_avg': {'precision': np.float64(0.7999715475938042), 'recall': np.float64(0.8192055187836648), 'f1': np.float64(0.8018281767055743)}, 'roc_auc': np.float64(0.8103352909562409)}, 'test': {'classification_report': {'0': {'precision': 0.6391096979332274, 'recall': 0.39105058365758755, 'f1-score': 0.4852142426071213, 'support': 1028.0}, '1': {'precision': 0.853704136480486, 'recall': 0.9414948453608247, 'f1-score': 0.8954528741267312, 'support': 3880.0}, 'accuracy': 0.8262021189894051, 'macro avg': {'precision': 0.7464069172068567, 'recall': 0.6662727145092061, 'f1-score': 0.6903335583669263, 'support': 4908.0}, 'weighted avg': {'precision': 0.8087564830928369, 'recall': 0.8262021189894051, 'f1-score': 0.809526771192306, 'support': 4908.0}}, 'roc_auc': np.float64(0.821776846243331)}}
# {'cv': {'class_0': {'precision': np.float64(0.548903870133727), 'recall': np.float64(0.49136326950537024), 'f1': np.float64(0.5184140354874548)}, 'class_1': {'precision': np.float64(0.8688124231306793), 'recall': np.float64(0.8928272772275584), 'f1': np.float64(0.8806447327635503)}, 'macro_avg': {'precision': np.float64(0.7088581466322031), 'recall': np.float64(0.6920952733664643), 'f1': np.float64(0.6995293841255026)}, 'weighted_avg': {'precision': np.float64(0.8017831883636664), 'recall': np.float64(0.8087100350593791), 'f1': np.float64(0.8047478984336175)}, 'roc_auc': np.float64(0.8107076426835033)}, 'test': {'classification_report': {'0': {'precision': 0.5709497206703911, 'recall': 0.4970817120622568, 'f1-score': 0.531461258450338, 'support': 1028.0}, '1': {'precision': 0.871168701719412, 'recall': 0.9010309278350516, 'f1-score': 0.8858482199417205, 'support': 3880.0}, 'accuracy': 0.8164221678891606, 'macro avg': {'precision': 0.7210592111949015, 'recall': 0.6990563199486541, 'f1-score': 0.7086547391960292, 'support': 4908.0}, 'weighted avg': {'precision': 0.8082866494540506, 'recall': 0.8164221678891606, 'f1-score': 0.8116204700612923, 'support': 4908.0}}, 'roc_auc': np.float64(0.8199950359019615)}}
# {'cv': {'class_0': {'precision': np.float64(0.5524340248982126), 'recall': np.float64(0.49987198930977705), 'f1': np.float64(0.5247230318434019)}, 'class_1': {'precision': np.float64(0.8706961406091095), 'recall': np.float64(0.8925693791508718), 'f1': np.float64(0.8814863884630141)}, 'macro_avg': {'precision': np.float64(0.711565082753661), 'recall': np.float64(0.6962206842303245), 'f1': np.float64(0.703104710153208)}, 'weighted_avg': {'precision': np.float64(0.8040118776483902), 'recall': np.float64(0.8102889734241054), 'f1': np.float64(0.8067351054382325)}, 'roc_auc': np.float64(0.8111984054679058)}, 'test': {'classification_report': {'0': {'precision': 0.5684782608695652, 'recall': 0.5087548638132295, 'f1-score': 0.5369609856262834, 'support': 1028.0}, '1': {'precision': 0.873370110330993, 'recall': 0.897680412371134, 'f1-score': 0.8853584138281647, 'support': 3880.0}, 'accuracy': 0.8162184189079055, 'macro avg': {'precision': 0.720924185600279, 'recall': 0.7032176380921817, 'f1-score': 0.711159699727224, 'support': 4908.0}, 'weighted avg': {'precision': 0.8095093073060647, 'recall': 0.8162184189079055, 'f1-score': 0.8123851953702319, 'support': 4908.0}}, 'roc_auc': np.float64(0.821708151149264)}}
# {'cv': {'class_0': {'precision': np.float64(0.5595182937284692), 'recall': np.float64(0.479939571858934), 'f1': np.float64(0.516576985372944)}, 'class_1': {'precision': np.float64(0.8671447025486942), 'recall': np.float64(0.899722853008894), 'f1': np.float64(0.8831248404400505)}, 'macro_avg': {'precision': np.float64(0.7133314981385817), 'recall': np.float64(0.689831212433914), 'f1': np.float64(0.6998509129064973)}, 'weighted_avg': {'precision': np.float64(0.8026888992131066), 'recall': np.float64(0.8117672424449722), 'f1': np.float64(0.8063234482907377)}, 'roc_auc': np.float64(0.8111564532879957)}, 'test': {'classification_report': {'0': {'precision': 0.5767441860465117, 'recall': 0.48249027237354086, 'f1-score': 0.5254237288135594, 'support': 1028.0}, '1': {'precision': 0.8685770750988142, 'recall': 0.9061855670103093, 'f1-score': 0.8869828456104945, 'support': 3880.0}, 'accuracy': 0.8174409127954361, 'macro avg': {'precision': 0.7226606305726629, 'recall': 0.694337919691925, 'f1-score': 0.706203287212027, 'support': 4908.0}, 'weighted avg': {'precision': 0.8074515229501249, 'recall': 0.8174409127954361, 'f1-score': 0.8112528594517232, 'support': 4908.0}}, 'roc_auc': np.float64(0.8215290174094428)}}
# {'cv': {'class_0': {'precision': np.float64(0.5538557420950251), 'recall': np.float64(0.47337614152720003), 'f1': np.float64(0.510380752228311)}, 'class_1': {'precision': np.float64(0.8655749354466611), 'recall': np.float64(0.8988207288590024), 'f1': np.float64(0.8818778993800969)}, 'macro_avg': {'precision': np.float64(0.709715338770843), 'recall': np.float64(0.6860984351931012), 'f1': np.float64(0.696129325804204)}, 'weighted_avg': {'precision': np.float64(0.8002615863760916), 'recall': np.float64(0.8096789261236126), 'f1': np.float64(0.8040395006926137)}, 'roc_auc': np.float64(0.811935937757186)}, 'test': {'classification_report': {'0': {'precision': 0.5763490241102182, 'recall': 0.4883268482490272, 'f1-score': 0.5286993154291733, 'support': 1028.0}, '1': {'precision': 0.8697052266534555, 'recall': 0.9048969072164949, 'f1-score': 0.8869521283314387, 'support': 3880.0}, 'accuracy': 0.8176446617766912, 'macro avg': {'precision': 0.7230271253818368, 'recall': 0.696611877732761, 'f1-score': 0.7078257218803059, 'support': 4908.0}, 'weighted avg': {'precision': 0.8082606104728426, 'recall': 0.8176446617766912, 'f1-score': 0.8119146605923333, 'support': 4908.0}}, 'roc_auc': np.float64(0.8199383749849573)}}
# {'cv': {'class_0': {'precision': np.float64(0.5535858539129856), 'recall': np.float64(0.48966306285531835), 'f1': np.float64(0.5195486729106324)}, 'class_1': {'precision': np.float64(0.8687352171401868), 'recall': np.float64(0.8952116508467031), 'f1': np.float64(0.8817645598609681)}, 'macro_avg': {'precision': np.float64(0.7111605355265862), 'recall': np.float64(0.6924373568510107), 'f1': np.float64(0.7006566163858003)}, 'weighted_avg': {'precision': np.float64(0.8027031574889653), 'recall': np.float64(0.8102385819517176), 'f1': np.float64(0.8058708286828362)}, 'roc_auc': np.float64(0.8114873826981439)}, 'test': {'classification_report': {'0': {'precision': 0.5736782902137233, 'recall': 0.4961089494163424, 'f1-score': 0.5320813771517997, 'support': 1028.0}, '1': {'precision': 0.8711122169693953, 'recall': 0.902319587628866, 'f1-score': 0.8864413216862894, 'support': 3880.0}, 'accuracy': 0.8172371638141809, 'macro avg': {'precision': 0.7223952535915593, 'recall': 0.6992142685226042, 'f1-score': 0.7092613494190445, 'support': 4908.0}, 'weighted avg': {'precision': 0.8088135053343442, 'recall': 0.8172371638141809, 'f1-score': 0.8122192306142733, 'support': 4908.0}}, 'roc_auc': np.float64(0.8214276043964861)}}

# %%
with open('/content/xgb_sv123(50).pkl', 'rb') as f:
    data6 = pickle.load(f)
    model123 = data6['model']

with open('/content/xgb_sv135(50).pkl', 'rb') as f:
    data7 = pickle.load(f)
    model135 = data7['model']

with open('/content/xgb_sv345(50).pkl', 'rb') as f:
    data8 = pickle.load(f)
    model345 = data8['model']

# %%
model_sv
# Out:
# VotingClassifier(estimators=[('model2',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.990071849456466,
#                                             device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             gamma=0.3988516844389491,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interactio...
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.03306822858156492,
#                                             max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=4,
#                                             max_leaves=None, min_child_weight=5,
#                                             missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=478, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...))],
#                  voting='soft')

# %%
from sklearn.ensemble import VotingClassifier

# %%
# 이미 학습된 모델들 (예: model4, model5, model3)
soft_voting_model = VotingClassifier(
    estimators=[('model4', model4), ('model5', model5), ('model3', model3)],
    voting='soft'
)

# %%
def evaluate_model_general(model, X_trainval, y_trainval, X_test, y_test, cv=5):
    skf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=42)

    # 결과 저장 리스트
    precision_0, recall_0, f1_0 = [], [], []
    precision_1, recall_1, f1_1 = [], [], []
    roc_auc_list = []

    for train_idx, val_idx in skf.split(X_trainval, y_trainval):
        X_train, X_val = X_trainval.iloc[train_idx], X_trainval.iloc[val_idx]
        y_train, y_val = y_trainval.iloc[train_idx], y_trainval.iloc[val_idx]

        # 모델 학습
        model.fit(X_train, y_train)

        # 예측 및 확률
        y_pred = model.predict(X_val)
        y_proba = model.predict_proba(X_val)[:, 1]

        report = classification_report(y_val, y_pred, output_dict=True)
        auc = roc_auc_score(y_val, y_proba)

        # 클래스별 지표
        precision_0.append(report['0']['precision'])
        recall_0.append(report['0']['recall'])
        f1_0.append(report['0']['f1-score'])

        precision_1.append(report['1']['precision'])
        recall_1.append(report['1']['recall'])
        f1_1.append(report['1']['f1-score'])

        roc_auc_list.append(auc)

    # 평균 계산
    avg_p0, avg_r0, avg_f0 = np.mean(precision_0), np.mean(recall_0), np.mean(f1_0)
    avg_p1, avg_r1, avg_f1 = np.mean(precision_1), np.mean(recall_1), np.mean(f1_1)

    total_support_0 = sum([report['0']['support'] for report in [classification_report(y_trainval.iloc[val_idx], model.predict(X_trainval.iloc[val_idx]), output_dict=True) for _, val_idx in skf.split(X_trainval, y_trainval)]]) / cv
    total_support_1 = sum([report['1']['support'] for report in [classification_report(y_trainval.iloc[val_idx], model.predict(X_trainval.iloc[val_idx]), output_dict=True) for _, val_idx in skf.split(X_trainval, y_trainval)]]) / cv
    total_support = total_support_0 + total_support_1

    macro_precision = (avg_p0 + avg_p1) / 2
    macro_recall = (avg_r0 + avg_r1) / 2
    macro_f1 = (avg_f0 + avg_f1) / 2

    weighted_precision = (avg_p0 * total_support_0 + avg_p1 * total_support_1) / total_support
    weighted_recall = (avg_r0 * total_support_0 + avg_r1 * total_support_1) / total_support
    weighted_f1 = (avg_f0 * total_support_0 + avg_f1 * total_support_1) / total_support

    print("📄 모델 성능 (5-Fold 평균 기반)")
    print(f"Class 0 - Precision: {avg_p0:.4f}, Recall: {avg_r0:.4f}, F1: {avg_f0:.4f}")
    print(f"Class 1 - Precision: {avg_p1:.4f}, Recall: {avg_r1:.4f}, F1: {avg_f1:.4f}")
    print(f"Macro Avg     - Precision: {macro_precision:.4f}, Recall: {macro_recall:.4f}, F1: {macro_f1:.4f}")
    print(f"Weighted Avg  - Precision: {weighted_precision:.4f}, Recall: {weighted_recall:.4f}, F1: {weighted_f1:.4f}")
    print(f"ROC AUC 평균: {np.mean(roc_auc_list):.4f}")

    # 테스트셋 평가
    model.fit(X_trainval, y_trainval)
    y_test_pred = model.predict(X_test)
    y_test_proba = model.predict_proba(X_test)[:, 1]

    print("\n📊 모델 성능 (Test Set)")
    print(classification_report(y_test, y_test_pred))
    print(f"ROC AUC Score: {roc_auc_score(y_test, y_test_proba):.4f}")

    return {
        "cv": {
            "class_0": {"precision": avg_p0, "recall": avg_r0, "f1": avg_f0},
            "class_1": {"precision": avg_p1, "recall": avg_r1, "f1": avg_f1},
            "macro_avg": {"precision": macro_precision, "recall": macro_recall, "f1": macro_f1},
            "weighted_avg": {"precision": weighted_precision, "recall": weighted_recall, "f1": weighted_f1},
            "roc_auc": np.mean(roc_auc_list)
        },
        "test": {
            "classification_report": classification_report(y_test, y_test_pred, output_dict=True),
            "roc_auc": roc_auc_score(y_test, y_test_proba)
        }
    }

# %%
result_voting=evaluate_model_general(model_sv, X_trainval, y_trainval, X_test, y_test)
save_model_and_results(model_sv, result_voting, "/content/xgb_sv.pkl")
# Out:
# 📄 모델 성능 (5-Fold 평균 기반)
# Class 0 - Precision: 0.5536, Recall: 0.4897, F1: 0.5195
# Class 1 - Precision: 0.8687, Recall: 0.8952, F1: 0.8818
# Macro Avg     - Precision: 0.7112, Recall: 0.6924, F1: 0.7007
# Weighted Avg  - Precision: 0.8027, Recall: 0.8102, F1: 0.8059
# ROC AUC 평균: 0.8115
#
# 📊 모델 성능 (Test Set)
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53      1028
#            1       0.87      0.90      0.89      3880
#
#     accuracy                           0.82      4908
#    macro avg       0.72      0.70      0.71      4908
# weighted avg       0.81      0.82      0.81      4908
#
# ROC AUC Score: 0.8214
# '/content/xgb_sv.pkl'

# %%
# Out:
# '/content/xgb_sv123(50).pkl'
